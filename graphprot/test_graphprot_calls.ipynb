# %%
# %%bash
#
# # prepare example sequences, using 25 positives and 25 negatives
# head -n 50 \
# /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa \
# | head -n 50 > graphprot/example_seqs//dummy25.positives.fa
#
# head -n 50 \
# /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.negatives.fa \
# | head -n 50 > graphprot/example_seqs/dummy25.negatives.fa
# Out:
# bash: line 5: graphprot/example_seqs//dummy25.positives.fa: No such file or directory
# head: write error: Broken pipe
# head: write error
# bash: line 9: graphprot/example_seqs/dummy25.negatives.fa: No such file or directory
# head: write error: Broken pipe
# head: write error

# %%
# %%bash
#
# # minimal call graphprot fit
# time ./graphprot_seqmodel -vv fit \
# -p /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa \
# -n /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.negatives.fa
# Out:
# --------------------------------------------------------------------------------
# Program: graphprot_seqmodel
# Called with parameters:
#  block_size: None
#         cv: 10
# fit_vectorizer: False
# lower_bound_threshold_negative: -1
# lower_bound_threshold_positive: -1
# max_total_time: -1
# model_file: model
# n_active_learning_iterations: 0
#   n_blocks: 8
# n_inner_iter_estimator: 5
#     n_iter: 20
#     n_jobs: 2
#      nbits: 20
# negative_input_file: /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.negatives.fa
# no_logging: False
# output_dir_path: out
# positive_input_file: /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa
# pre_processor_block_size: None
# pre_processor_n_blocks: 10
# pre_processor_n_jobs: 4
# random_state: 1
#    scoring: roc_auc
# size_negative: -1
# size_positive: -1
# two_steps_optimization: False
# upper_bound_threshold_negative: 1
# upper_bound_threshold_positive: 1
#  verbosity: 2
#      which: fit
#
#
# 	Parameters range:
#
# Pre_processor:
#
#
# Vectorizer:
#          d: [4, 0, 1, 2, 3, 4, 5, 6]
#      nbits: [14, 16, 18]
#          r: [1, 0, 2, 3, 4]
#
# Estimator:
#      alpha: [1e-08, 1e-07, 1e-06, 1e-05, 0.0001, 0.001, 0.01, 0.1]
#       eta0: [0.0001, 0.001, 0.01]
#   l1_ratio: [ 0.81780008  0.14791246  0.70598977  0.1083798   0.34248062  0.59083973
#   0.14667059  0.30708486  0.24221214  0.37275525  0.21815981  0.23293732
#   0.32988679  0.6399523   0.80801941  0.85231174  0.35110292  0.26620719
#   0.78233755  0.73744262]
# learning_rate: ['invscaling', 'constant', 'optimal']
#       loss: ['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron']
#     n_iter: [ 53  40 169   5   6 145 104  25  25  10 150 111  54 190  78 144  43  24
#   60   6]
#     n_jobs: [-1]
#    penalty: ['l1', 'l2', 'elasticnet']
#    power_t: [ 0.29998901  0.35583682  0.30803876  0.37320002  0.3697523   0.77613116
#   0.84828731  0.57830562  0.24263002  0.82294111  0.64539131  0.3159899
#   0.13177721  0.89900644  0.4385562   0.65971298  0.39233924  0.26900603
#   0.23457468  0.2987279 ]
# iteration: (1/5) 1/20 score (roc_auc): 0.625 (0.681 +- 0.056)
#
#
# 	Iteration: 1/20 (after 47.1 sec; 0:00:47.099658)
# Best score (roc_auc): 0.625 (0.681 +- 0.056)
#
# Data:
# Instances: 1000 ; Features: 16385 with an avg of 808 features per instance
# class: 1 count:500 (0.50)	class: -1 count:500 (0.50)
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
#          d: 4
#      nbits: 14
#          r: 1
#
# Estimator:
#      alpha: 0.01
#       eta0: 0.001
#   l1_ratio: 0.852311742337
# learning_rate: invscaling
#       loss: squared_hinge
#     n_iter: 43
#     n_jobs: -1
#    penalty: l1
#    power_t: 0.776131161802
# iteration: (2/5) 1/20 score (roc_auc): 0.770 (0.794 +- 0.024)
#
#
# 	Iteration: 1/20 (after 49.6 sec; 0:00:49.632806)
# Best score (roc_auc): 0.770 (0.794 +- 0.024)
#
# Data:
# Instances: 1000 ; Features: 16385 with an avg of 808 features per instance
# class: 1 count:500 (0.50)	class: -1 count:500 (0.50)
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
#          d: 4
#      nbits: 14
#          r: 1
#
# Estimator:
#      alpha: 1e-05
#       eta0: 0.0001
#   l1_ratio: 0.342480619025
# learning_rate: optimal
#       loss: squared_hinge
#     n_iter: 43
#     n_jobs: -1
#    penalty: l1
#    power_t: 0.659712975791
# iteration: (3/5) 1/20 score (roc_auc): 0.729 (0.757 +- 0.028)
# iteration: (4/5) 1/20 score (roc_auc): 0.730 (0.758 +- 0.028)
# iteration: (5/5) 1/20 score (roc_auc): 0.392 (0.440 +- 0.047)
# iteration: (1/5) 2/20 score (roc_auc): 0.766 (0.788 +- 0.022)
# iteration: (2/5) 2/20 score (roc_auc): 0.780 (0.801 +- 0.021)
#
#
# 	Iteration: 2/20 (after 286.8 sec; 0:04:46.787140)
# Best score (roc_auc): 0.780 (0.801 +- 0.021)
#
# Data:
# Instances: 1000 ; Features: 262145 with an avg of 3000 features per instance
# class: 1 count:500 (0.50)	class: -1 count:500 (0.50)
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
#          d: 2
#      nbits: 18
#          r: 4
#
# Estimator:
#      alpha: 1e-05
#       eta0: 0.001
#   l1_ratio: 0.307084861047
# learning_rate: constant
#       loss: squared_hinge
#     n_iter: 144
#     n_jobs: -1
#    penalty: l1
#    power_t: 0.37320002157
# iteration: (3/5) 2/20 score (roc_auc): 0.813 (0.831 +- 0.017)
#
#
# 	Iteration: 2/20 (after 315.2 sec; 0:05:15.226684)
# Best score (roc_auc): 0.813 (0.831 +- 0.017)
#
# Data:
# Instances: 1000 ; Features: 262145 with an avg of 3000 features per instance
# class: 1 count:500 (0.50)	class: -1 count:500 (0.50)
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
#          d: 2
#      nbits: 18
#          r: 4
#
# Estimator:
#      alpha: 0.0001
#       eta0: 0.001
#   l1_ratio: 0.80801941046
# learning_rate: optimal
#       loss: hinge
#     n_iter: 144
#     n_jobs: -1
#    penalty: l2
#    power_t: 0.578305623614
# iteration: (4/5) 2/20 score (roc_auc): 0.740 (0.764 +- 0.024)
# iteration: (5/5) 2/20 score (roc_auc): 0.805 (0.827 +- 0.022)
# iteration: (1/5) 3/20 score (roc_auc): 0.747 (0.771 +- 0.024)
# iteration: (2/5) 3/20 score (roc_auc): 0.741 (0.763 +- 0.023)
# iteration: (3/5) 3/20 score (roc_auc): 0.212 (0.236 +- 0.024)
# iteration: (4/5) 3/20 score (roc_auc): 0.740 (0.763 +- 0.023)
# iteration: (5/5) 3/20 score (roc_auc): 0.739 (0.762 +- 0.023)
# iteration: (1/5) 4/20 score (roc_auc): 0.733 (0.759 +- 0.026)
# iteration: (2/5) 4/20 score (roc_auc): 0.198 (0.231 +- 0.033)
# iteration: (3/5) 4/20 score (roc_auc): 0.766 (0.790 +- 0.024)
# iteration: (4/5) 4/20 score (roc_auc): 0.730 (0.752 +- 0.023)
# iteration: (5/5) 4/20 score (roc_auc): 0.202 (0.229 +- 0.027)
# iteration: (1/5) 5/20 score (roc_auc): 0.721 (0.749 +- 0.028)
# iteration: (2/5) 5/20 score (roc_auc): 0.721 (0.749 +- 0.028)
# iteration: (3/5) 5/20 score (roc_auc): 0.232 (0.297 +- 0.065)
# iteration: (4/5) 5/20 score (roc_auc): 0.723 (0.751 +- 0.028)
# iteration: (5/5) 5/20 score (roc_auc): 0.731 (0.758 +- 0.026)
# iteration: (1/5) 6/20 score (roc_auc): 0.782 (0.803 +- 0.021)
# iteration: (2/5) 6/20 score (roc_auc): 0.733 (0.760 +- 0.027)
# iteration: (3/5) 6/20 score (roc_auc): 0.784 (0.806 +- 0.022)
# iteration: (4/5) 6/20 score (roc_auc): 0.170 (0.193 +- 0.023)
# iteration: (5/5) 6/20 score (roc_auc): 0.804 (0.824 +- 0.020)
# iteration: (1/5) 7/20 score (roc_auc): 0.219 (0.248 +- 0.029)
# iteration: (2/5) 7/20 score (roc_auc): 0.725 (0.755 +- 0.030)
# iteration: (3/5) 7/20 score (roc_auc): 0.726 (0.756 +- 0.030)
# iteration: (4/5) 7/20 score (roc_auc): 0.723 (0.753 +- 0.030)
# iteration: (5/5) 7/20 score (roc_auc): 0.724 (0.754 +- 0.030)
# iteration: (1/5) 8/20 score (roc_auc): 0.198 (0.228 +- 0.029)
# iteration: (2/5) 8/20 score (roc_auc): 0.799 (0.826 +- 0.027)
# iteration: (3/5) 8/20 score (roc_auc): 0.734 (0.764 +- 0.030)
# iteration: (4/5) 8/20 score (roc_auc): 0.201 (0.227 +- 0.026)
# iteration: (5/5) 8/20 score (roc_auc): 0.227 (0.263 +- 0.036)
# iteration: (1/5) 9/20 score (roc_auc): 0.774 (0.802 +- 0.028)
# iteration: (2/5) 9/20 score (roc_auc): 0.785 (0.805 +- 0.020)
# iteration: (3/5) 9/20 score (roc_auc): 0.783 (0.811 +- 0.027)
# iteration: (4/5) 9/20 score (roc_auc): 0.198 (0.223 +- 0.026)
# iteration: (5/5) 9/20 score (roc_auc): 0.781 (0.805 +- 0.024)
# iteration: (1/5) 10/20 score (roc_auc): 0.765 (0.795 +- 0.030)
# iteration: (2/5) 10/20 score (roc_auc): 0.216 (0.245 +- 0.029)
# iteration: (3/5) 10/20 score (roc_auc): 0.764 (0.794 +- 0.029)
# iteration: (4/5) 10/20 score (roc_auc): 0.723 (0.753 +- 0.030)
# iteration: (5/5) 10/20 score (roc_auc): 0.723 (0.752 +- 0.030)
# iteration: (1/5) 11/20 score (roc_auc): 0.744 (0.770 +- 0.026)
# iteration: (2/5) 11/20 score (roc_auc): 0.171 (0.195 +- 0.024)
# iteration: (3/5) 11/20 score (roc_auc): 0.739 (0.765 +- 0.025)
# iteration: (4/5) 11/20 score (roc_auc): 0.739 (0.763 +- 0.024)
# iteration: (5/5) 11/20 score (roc_auc): 0.810 (0.828 +- 0.019)
# iteration: (1/5) 12/20 score (roc_auc): 0.744 (0.765 +- 0.021)
# iteration: (2/5) 12/20 score (roc_auc): 0.747 (0.767 +- 0.020)
# iteration: (3/5) 12/20 score (roc_auc): 0.750 (0.770 +- 0.020)
# iteration: (4/5) 12/20 score (roc_auc): 0.719 (0.746 +- 0.027)
# iteration: (5/5) 12/20 score (roc_auc): 0.749 (0.769 +- 0.020)
# iteration: (1/5) 13/20 score (roc_auc): 0.205 (0.233 +- 0.029)
# iteration: (2/5) 13/20 score (roc_auc): 0.751 (0.779 +- 0.027)
# iteration: (3/5) 13/20 score (roc_auc): 0.543 (0.592 +- 0.050)
# iteration: (4/5) 13/20 score (roc_auc): 0.738 (0.767 +- 0.029)
# iteration: (5/5) 13/20 score (roc_auc): 0.205 (0.233 +- 0.029)
# iteration: (1/5) 14/20 score (roc_auc): 0.724 (0.751 +- 0.026)
# iteration: (2/5) 14/20 score (roc_auc): 0.217 (0.246 +- 0.029)
# iteration: (3/5) 14/20 score (roc_auc): 0.725 (0.751 +- 0.026)
# iteration: (4/5) 14/20 score (roc_auc): 0.763 (0.798 +- 0.034)
# iteration: (5/5) 14/20 score (roc_auc): 0.723 (0.750 +- 0.026)
# iteration: (1/5) 15/20 score (roc_auc): 0.760 (0.787 +- 0.027)
# iteration: (2/5) 15/20 score (roc_auc): 0.737 (0.762 +- 0.024)
# iteration: (3/5) 15/20 score (roc_auc): 0.774 (0.796 +- 0.021)
# iteration: (4/5) 15/20 score (roc_auc): 0.214 (0.238 +- 0.024)
# iteration: (5/5) 15/20 score (roc_auc): 0.759 (0.792 +- 0.034)
# iteration: (1/5) 16/20 score (roc_auc): 0.217 (0.245 +- 0.028)
# iteration: (2/5) 16/20 score (roc_auc): 0.726 (0.754 +- 0.028)
# iteration: (3/5) 16/20 score (roc_auc): 0.726 (0.754 +- 0.028)
# iteration: (4/5) 16/20 score (roc_auc): 0.740 (0.767 +- 0.027)
# iteration: (5/5) 16/20 score (roc_auc): 0.769 (0.797 +- 0.028)
# iteration: (1/5) 17/20 score (roc_auc): 0.738 (0.763 +- 0.026)
# iteration: (2/5) 17/20 score (roc_auc): 0.789 (0.810 +- 0.021)
# iteration: (3/5) 17/20 score (roc_auc): 0.811 (0.829 +- 0.018)
# iteration: (4/5) 17/20 score (roc_auc): 0.210 (0.237 +- 0.027)
# iteration: (5/5) 17/20 score (roc_auc): 0.211 (0.247 +- 0.037)
# iteration: (1/5) 18/20 score (roc_auc): 0.217 (0.248 +- 0.031)
# iteration: (2/5) 18/20 score (roc_auc): 0.738 (0.764 +- 0.026)
# iteration: (3/5) 18/20 score (roc_auc): 0.740 (0.766 +- 0.026)
# iteration: (4/5) 18/20 score (roc_auc): 0.764 (0.789 +- 0.026)
# iteration: (5/5) 18/20 score (roc_auc): 0.760 (0.783 +- 0.024)
# iteration: (1/5) 19/20 score (roc_auc): 0.798 (0.821 +- 0.023)
# iteration: (2/5) 19/20 score (roc_auc): 0.800 (0.827 +- 0.027)
# iteration: (3/5) 19/20 score (roc_auc): 0.733 (0.758 +- 0.025)
# iteration: (4/5) 19/20 score (roc_auc): 0.799 (0.826 +- 0.026)
# iteration: (5/5) 19/20 score (roc_auc): 0.209 (0.237 +- 0.028)
# iteration: (1/5) 20/20 score (roc_auc): 0.796 (0.822 +- 0.026)
# iteration: (2/5) 20/20 score (roc_auc): 0.702 (0.740 +- 0.038)
# iteration: (3/5) 20/20 score (roc_auc): 0.784 (0.808 +- 0.024)
# iteration: (4/5) 20/20 score (roc_auc): 0.199 (0.234 +- 0.035)
# iteration: (5/5) 20/20 score (roc_auc): 0.739 (0.769 +- 0.031)
# Saved current best model in out/model
# Elapsed time: 2378.2 sec
# real	39m40.459s
# user	80m14.559s
# sys	1m24.161s

# %%
# %%bash
#
# # minimal call graphprot estimate
# time ./graphprot_seqmodel -vv estimate \
# -p /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa \
# -n /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.negatives.fa \
# -m out/model
# Out:
# --------------------------------------------------------------------------------
# Program: graphprot_seqmodel
# Called with parameters:
#  model_file: out/model
# negative_input_file: /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.negatives.fa
# no_logging: False
# output_dir_path: out
# positive_input_file: /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa
#  verbosity: 2
#      which: estimate
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
#          d: 2
#      nbits: 18
#          r: 4
#
# Estimator:
#      alpha: 0.0001
#       eta0: 0.001
#   l1_ratio: 0.80801941046
# learning_rate: optimal
#       loss: hinge
#     n_iter: 144
#     n_jobs: -1
#    penalty: l2
#    power_t: 0.578305623614
#
# Classifier:
# SGDClassifier(alpha=0.0001, average=True, class_weight='auto', epsilon=0.1,
#        eta0=0.001, fit_intercept=True, l1_ratio=0.80801941045998749,
#        learning_rate='optimal', loss='hinge', n_iter=144, n_jobs=-1,
#        penalty='l2', power_t=0.57830562361394044, random_state=None,
#        shuffle=True, verbose=0, warm_start=False)
#
# Data:
# Instances: 1000 ; Features: 262145 with an avg of 3000 features per instance
#
# Predictive performace estimate:
#              precision    recall  f1-score   support
#
#          -1       1.00      1.00      1.00       500
#           1       1.00      1.00      1.00       500
#
# avg / total       1.00      1.00      1.00      1000
#
# APR: 1.000
# ROC: 1.000
# Elapsed time: 55.4 sec
# real	0m57.136s
# user	1m57.958s
# sys	0m1.367s

# %%
# %%bash
#
# # minimal call graphprot predict
# time ./graphprot_seqmodel -vv predict \
# -i /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa \
# -m out/model
# Out:
# --------------------------------------------------------------------------------
# Program: graphprot_seqmodel
# Called with parameters:
#  input_file: /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa
# model_file: out/model
# no_logging: False
# output_dir_path: out
#  verbosity: 2
#      which: predict
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
#          d: 2
#      nbits: 18
#          r: 4
#
# Estimator:
#      alpha: 0.0001
#       eta0: 0.001
#   l1_ratio: 0.80801941046
# learning_rate: optimal
#       loss: hinge
#     n_iter: 144
#     n_jobs: -1
#    penalty: l2
#    power_t: 0.578305623614
# Written file: out/predictions.txt (500 lines)
# Written file: out/classifications.txt (500 lines)
# Written file: out/info.txt (500 lines)
# Elapsed time: 29.5 sec
# real	0m30.460s
# user	1m0.512s
# sys	0m0.638s
