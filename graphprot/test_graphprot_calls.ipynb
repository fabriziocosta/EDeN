# %%
# %%bash
#
# # prepare example sequences, using 25 positives and 25 negatives
# head -n 50 \
# /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa \
# | head -n 50 > graphprot/example_seqs//dummy25.positives.fa
#
# head -n 50 \
# /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.negatives.fa \
# | head -n 50 > graphprot/example_seqs/dummy25.negatives.fa
# Out:
# bash: line 5: graphprot/example_seqs//dummy25.positives.fa: No such file or directory
# head: write error: Broken pipe
# head: write error
# bash: line 9: graphprot/example_seqs/dummy25.negatives.fa: No such file or directory
# head: write error: Broken pipe
# head: write error

# %%
# %%bash
#
# # minimal call graphprot fit
# time ./graphprot_seqmodel -vv fit \
# -p /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa \
# -n /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.negatives.fa
# Out:
# --------------------------------------------------------------------------------
# Program: graphprot_seqmodel
# Called with parameters:
#  block_size: None
#         cv: 10
# fit_vectorizer: False
# lower_bound_threshold_negative: -1
# lower_bound_threshold_positive: -1
# max_total_time: -1
# model_file: model
# n_active_learning_iterations: 0
#   n_blocks: 8
# n_inner_iter_estimator: 5
#     n_iter: 20
#     n_jobs: 2
#      nbits: 20
# negative_input_file: /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.negatives.fa
# no_logging: False
# output_dir_path: out
# positive_input_file: /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa
# pre_processor_block_size: None
# pre_processor_n_blocks: 10
# pre_processor_n_jobs: 4
# random_state: 1
#    scoring: roc_auc
# size_negative: -1
# size_positive: -1
# two_steps_optimization: False
# upper_bound_threshold_negative: 1
# upper_bound_threshold_positive: 1
#  verbosity: 2
#      which: fit
#
#
# 	Parameters range:
#
# Pre_processor:
#
#
# Vectorizer:
# complexity: [1, 2]
#
# Estimator:
#      alpha: [1e-08, 1e-07, 1e-06, 1e-05, 0.0001, 0.001, 0.01, 0.1]
#       eta0: [0.0001, 0.001, 0.01]
#   l1_ratio: [ 0.34446409  0.87184006  0.66619592  0.59781363  0.22812666  0.83689844
#   0.73699478  0.88019153  0.75514639  0.47356754  0.54625267  0.77757736
#   0.55081172  0.61664592  0.1839166   0.42343136  0.11371735  0.28915558
#   0.29908936  0.40535186]
# learning_rate: ['invscaling', 'constant', 'optimal']
#       loss: ['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron']
#     n_iter: [176 104  94 198  54  70 135  49 182  42 180 139  31  43 157 191  37  23
#  189  19]
#     n_jobs: [-1]
#    penalty: ['l1', 'l2', 'elasticnet']
#    power_t: [ 0.52992298  0.44888751  0.94203941  0.54309023  0.88399845  0.32006393
#   0.28338458  0.57333641  0.33159955  0.1038603   0.48088607  0.81375252
#   0.37249754  0.96144107  0.21729581  0.7662847   0.67288124  0.81326229
#   0.68635393  0.27091316]
# iteration: (1/5) 1/20 score (roc_auc): 0.762 (0.784 +- 0.022)
#
#
# 	Iteration: 1/20 (after 28.8 sec; 0:00:28.832546)
# Best score (roc_auc): 0.762 (0.784 +- 0.022)
#
# Data:
# Instances: 1000 ; Features: 1048577 with an avg of 159 features per instance
# class: 1 count:500 (0.50)	class: -1 count:500 (0.50)
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
# complexity: 1
#
# Estimator:
#      alpha: 1e-06
#       eta0: 0.001
#   l1_ratio: 0.871840060393
# learning_rate: invscaling
#       loss: squared_hinge
#     n_iter: 191
#     n_jobs: -1
#    penalty: elasticnet
#    power_t: 0.103860303921
# iteration: (2/5) 1/20 score (roc_auc): 0.203 (0.230 +- 0.027)
# iteration: (3/5) 1/20 score (roc_auc): 0.728 (0.755 +- 0.027)
# iteration: (4/5) 1/20 score (roc_auc): 0.791 (0.808 +- 0.017)
#
#
# 	Iteration: 1/20 (after 38.8 sec; 0:00:38.804624)
# Best score (roc_auc): 0.791 (0.808 +- 0.017)
#
# Data:
# Instances: 1000 ; Features: 1048577 with an avg of 159 features per instance
# class: 1 count:500 (0.50)	class: -1 count:500 (0.50)
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
# complexity: 1
#
# Estimator:
#      alpha: 1e-07
#       eta0: 0.0001
#   l1_ratio: 0.344464087947
# learning_rate: optimal
#       loss: log
#     n_iter: 42
#     n_jobs: -1
#    penalty: l2
#    power_t: 0.883998453962
# iteration: (5/5) 1/20 score (roc_auc): 0.788 (0.809 +- 0.021)
# iteration: (1/5) 2/20 score (roc_auc): 0.786 (0.804 +- 0.018)
# iteration: (2/5) 2/20 score (roc_auc): 0.199 (0.228 +- 0.029)
# iteration: (3/5) 2/20 score (roc_auc): 0.761 (0.784 +- 0.024)
# iteration: (4/5) 2/20 score (roc_auc): 0.782 (0.802 +- 0.020)
# iteration: (5/5) 2/20 score (roc_auc): 0.212 (0.238 +- 0.027)
# iteration: (1/5) 3/20 score (roc_auc): 0.280 (0.343 +- 0.063)
# iteration: (2/5) 3/20 score (roc_auc): 0.791 (0.811 +- 0.021)
#
#
# 	Iteration: 3/20 (after 223.5 sec; 0:03:43.519018)
# Best score (roc_auc): 0.791 (0.811 +- 0.021)
#
# Data:
# Instances: 1000 ; Features: 1048577 with an avg of 1121 features per instance
# class: 1 count:500 (0.50)	class: -1 count:500 (0.50)
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
# complexity: 2
#
# Estimator:
#      alpha: 0.0001
#       eta0: 0.001
#   l1_ratio: 0.550811724888
# learning_rate: constant
#       loss: modified_huber
#     n_iter: 198
#     n_jobs: -1
#    penalty: l2
#    power_t: 0.103860303921
# iteration: (3/5) 3/20 score (roc_auc): 0.785 (0.801 +- 0.016)
# iteration: (4/5) 3/20 score (roc_auc): 0.732 (0.759 +- 0.026)
# iteration: (5/5) 3/20 score (roc_auc): 0.746 (0.772 +- 0.026)
# iteration: (1/5) 4/20 score (roc_auc): 0.776 (0.795 +- 0.019)
# iteration: (2/5) 4/20 score (roc_auc): 0.787 (0.804 +- 0.017)
# iteration: (3/5) 4/20 score (roc_auc): 0.744 (0.768 +- 0.024)
# iteration: (4/5) 4/20 score (roc_auc): 0.729 (0.756 +- 0.027)
# iteration: (5/5) 4/20 score (roc_auc): 0.790 (0.804 +- 0.015)
# iteration: (1/5) 5/20 score (roc_auc): 0.211 (0.238 +- 0.027)
# iteration: (2/5) 5/20 score (roc_auc): 0.773 (0.796 +- 0.023)
# iteration: (3/5) 5/20 score (roc_auc): 0.790 (0.808 +- 0.018)
# iteration: (4/5) 5/20 score (roc_auc): 0.212 (0.239 +- 0.027)
# iteration: (5/5) 5/20 score (roc_auc): 0.731 (0.759 +- 0.028)
# iteration: (1/5) 6/20 score (roc_auc): 0.735 (0.762 +- 0.027)
# iteration: (2/5) 6/20 score (roc_auc): 0.743 (0.770 +- 0.027)
# iteration: (3/5) 6/20 score (roc_auc): 0.730 (0.758 +- 0.028)
# iteration: (4/5) 6/20 score (roc_auc): 0.656 (0.701 +- 0.045)
# iteration: (5/5) 6/20 score (roc_auc): 0.640 (0.696 +- 0.056)
# iteration: (1/5) 7/20 score (roc_auc): 0.728 (0.755 +- 0.027)
# iteration: (2/5) 7/20 score (roc_auc): 0.218 (0.245 +- 0.028)
# iteration: (3/5) 7/20 score (roc_auc): 0.727 (0.755 +- 0.027)
# iteration: (4/5) 7/20 score (roc_auc): 0.728 (0.754 +- 0.026)
# iteration: (5/5) 7/20 score (roc_auc): 0.728 (0.755 +- 0.027)
# iteration: (1/5) 8/20 score (roc_auc): 0.778 (0.796 +- 0.019)
# iteration: (2/5) 8/20 score (roc_auc): 0.627 (0.666 +- 0.039)
# iteration: (3/5) 8/20 score (roc_auc): 0.725 (0.753 +- 0.028)
# iteration: (4/5) 8/20 score (roc_auc): 0.188 (0.209 +- 0.021)
# iteration: (5/5) 8/20 score (roc_auc): 0.186 (0.214 +- 0.028)
# iteration: (1/5) 9/20 score (roc_auc): 0.735 (0.762 +- 0.027)
# iteration: (2/5) 9/20 score (roc_auc): 0.762 (0.785 +- 0.023)
# iteration: (3/5) 9/20 score (roc_auc): 0.788 (0.809 +- 0.021)
# iteration: (4/5) 9/20 score (roc_auc): 0.728 (0.756 +- 0.028)
# iteration: (5/5) 9/20 score (roc_auc): 0.211 (0.238 +- 0.027)
# iteration: (1/5) 10/20 score (roc_auc): 0.723 (0.752 +- 0.029)
# iteration: (2/5) 10/20 score (roc_auc): 0.220 (0.247 +- 0.027)
# iteration: (3/5) 10/20 score (roc_auc): 0.218 (0.246 +- 0.027)
# iteration: (4/5) 10/20 score (roc_auc): 0.187 (0.217 +- 0.030)
# iteration: (5/5) 10/20 score (roc_auc): 0.785 (0.805 +- 0.020)
# iteration: (1/5) 11/20 score (roc_auc): 0.726 (0.753 +- 0.026)
# iteration: (2/5) 11/20 score (roc_auc): 0.785 (0.804 +- 0.018)
# iteration: (3/5) 11/20 score (roc_auc): 0.766 (0.788 +- 0.022)
# iteration: (4/5) 11/20 score (roc_auc): 0.731 (0.758 +- 0.027)
# iteration: (5/5) 11/20 score (roc_auc): 0.741 (0.767 +- 0.025)
# iteration: (1/5) 12/20 score (roc_auc): 0.733 (0.759 +- 0.027)
# iteration: (2/5) 12/20 score (roc_auc): 0.795 (0.810 +- 0.015)
#
#
# 	Iteration: 12/20 (after 782.9 sec; 0:13:02.852483)
# Best score (roc_auc): 0.795 (0.810 +- 0.015)
#
# Data:
# Instances: 1000 ; Features: 1048577 with an avg of 159 features per instance
# class: 1 count:500 (0.50)	class: -1 count:500 (0.50)
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
# complexity: 1
#
# Estimator:
#      alpha: 0.01
#       eta0: 0.01
#   l1_ratio: 0.755146391226
# learning_rate: optimal
#       loss: perceptron
#     n_iter: 23
#     n_jobs: -1
#    penalty: l2
#    power_t: 0.480886074704
# iteration: (3/5) 12/20 score (roc_auc): 0.741 (0.766 +- 0.025)
# iteration: (4/5) 12/20 score (roc_auc): 0.780 (0.799 +- 0.019)
# iteration: (5/5) 12/20 score (roc_auc): 0.796 (0.815 +- 0.018)
#
#
# 	Iteration: 12/20 (after 787.7 sec; 0:13:07.689288)
# Best score (roc_auc): 0.796 (0.815 +- 0.018)
#
# Data:
# Instances: 1000 ; Features: 1048577 with an avg of 159 features per instance
# class: 1 count:500 (0.50)	class: -1 count:500 (0.50)
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
# complexity: 1
#
# Estimator:
#      alpha: 1e-05
#       eta0: 0.001
#   l1_ratio: 0.113717354478
# learning_rate: optimal
#       loss: squared_hinge
#     n_iter: 31
#     n_jobs: -1
#    penalty: l2
#    power_t: 0.372497536014
# iteration: (1/5) 13/20 score (roc_auc): 0.795 (0.816 +- 0.021)
# iteration: (2/5) 13/20 score (roc_auc): 0.787 (0.809 +- 0.021)
# iteration: (3/5) 13/20 score (roc_auc): 0.740 (0.765 +- 0.026)
# iteration: (4/5) 13/20 score (roc_auc): 0.774 (0.812 +- 0.038)
# iteration: (5/5) 13/20 score (roc_auc): 0.742 (0.765 +- 0.023)
# iteration: (1/5) 14/20 score (roc_auc): 0.214 (0.241 +- 0.027)
# iteration: (2/5) 14/20 score (roc_auc): 0.198 (0.233 +- 0.035)
# iteration: (3/5) 14/20 score (roc_auc): 0.774 (0.796 +- 0.022)
# iteration: (4/5) 14/20 score (roc_auc): 0.741 (0.766 +- 0.025)
# iteration: (5/5) 14/20 score (roc_auc): 0.788 (0.806 +- 0.018)
# iteration: (1/5) 15/20 score (roc_auc): 0.736 (0.762 +- 0.026)
# iteration: (2/5) 15/20 score (roc_auc): 0.799 (0.814 +- 0.015)
#
#
# 	Iteration: 15/20 (after 947.9 sec; 0:15:47.940218)
# Best score (roc_auc): 0.799 (0.814 +- 0.015)
#
# Data:
# Instances: 1000 ; Features: 1048577 with an avg of 159 features per instance
# class: 1 count:500 (0.50)	class: -1 count:500 (0.50)
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
# complexity: 1
#
# Estimator:
#      alpha: 0.001
#       eta0: 0.001
#   l1_ratio: 0.344464087947
# learning_rate: optimal
#       loss: perceptron
#     n_iter: 54
#     n_jobs: -1
#    penalty: l2
#    power_t: 0.283384579189
# iteration: (3/5) 15/20 score (roc_auc): 0.734 (0.767 +- 0.033)
# iteration: (4/5) 15/20 score (roc_auc): 0.778 (0.799 +- 0.021)
# iteration: (5/5) 15/20 score (roc_auc): 0.729 (0.756 +- 0.027)
# iteration: (1/5) 16/20 score (roc_auc): 0.211 (0.244 +- 0.032)
# iteration: (2/5) 16/20 score (roc_auc): 0.788 (0.810 +- 0.021)
# iteration: (3/5) 16/20 score (roc_auc): 0.755 (0.779 +- 0.024)
# iteration: (4/5) 16/20 score (roc_auc): 0.792 (0.810 +- 0.018)
# iteration: (5/5) 16/20 score (roc_auc): 0.735 (0.762 +- 0.027)
# iteration: (1/5) 17/20 score (roc_auc): 0.735 (0.763 +- 0.028)
# iteration: (2/5) 17/20 score (roc_auc): 0.211 (0.238 +- 0.027)
# iteration: (3/5) 17/20 score (roc_auc): 0.755 (0.779 +- 0.024)
# iteration: (4/5) 17/20 score (roc_auc): 0.797 (0.817 +- 0.020)
# iteration: (5/5) 17/20 score (roc_auc): 0.780 (0.802 +- 0.021)
# iteration: (1/5) 18/20 score (roc_auc): 0.795 (0.819 +- 0.024)
# iteration: (2/5) 18/20 score (roc_auc): 0.793 (0.811 +- 0.018)
# iteration: (3/5) 18/20 score (roc_auc): 0.730 (0.757 +- 0.027)
# iteration: (4/5) 18/20 score (roc_auc): 0.747 (0.771 +- 0.024)
# iteration: (5/5) 18/20 score (roc_auc): 0.724 (0.750 +- 0.026)
# iteration: (1/5) 19/20 score (roc_auc): 0.785 (0.803 +- 0.018)
# iteration: (2/5) 19/20 score (roc_auc): 0.775 (0.801 +- 0.026)
# iteration: (3/5) 19/20 score (roc_auc): 0.758 (0.782 +- 0.023)
# iteration: (4/5) 19/20 score (roc_auc): 0.789 (0.810 +- 0.020)
# iteration: (5/5) 19/20 score (roc_auc): 0.785 (0.806 +- 0.020)
# iteration: (1/5) 20/20 score (roc_auc): 0.785 (0.802 +- 0.017)
# iteration: (2/5) 20/20 score (roc_auc): 0.747 (0.791 +- 0.043)
# iteration: (3/5) 20/20 score (roc_auc): 0.778 (0.796 +- 0.018)
# iteration: (4/5) 20/20 score (roc_auc): 0.766 (0.788 +- 0.022)
# iteration: (5/5) 20/20 score (roc_auc): 0.749 (0.784 +- 0.035)
# Saved current best model in out/model
# Elapsed time: 1524.6 sec
# real	25m26.323s
# user	52m32.660s
# sys	0m43.182s

# %%
# %%bash
#
# # minimal call graphprot estimate
# time ./graphprot_seqmodel -vv estimate \
# -p /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa \
# -n /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.negatives.fa \
# -m out/model
# Out:
# --------------------------------------------------------------------------------
# Program: graphprot_seqmodel
# Called with parameters:
#  model_file: out/model
# negative_input_file: /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.negatives.fa
# no_logging: False
# output_dir_path: out
# positive_input_file: /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa
#  verbosity: 2
#      which: estimate
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
# complexity: 1
#
# Estimator:
#      alpha: 0.001
#       eta0: 0.001
#   l1_ratio: 0.344464087947
# learning_rate: optimal
#       loss: perceptron
#     n_iter: 54
#     n_jobs: -1
#    penalty: l2
#    power_t: 0.283384579189
#
# Classifier:
# SGDClassifier(alpha=0.001, average=True, class_weight='auto', epsilon=0.1,
#        eta0=0.001, fit_intercept=True, l1_ratio=0.34446408794724032,
#        learning_rate='optimal', loss='perceptron', n_iter=54, n_jobs=-1,
#        penalty='l2', power_t=0.28338457918883886, random_state=None,
#        shuffle=True, verbose=0, warm_start=False)
#
# Data:
# Instances: 1000 ; Features: 1048577 with an avg of 159 features per instance
#
# Predictive performace estimate:
#              precision    recall  f1-score   support
#
#          -1       0.79      0.79      0.79       500
#           1       0.79      0.79      0.79       500
#
# avg / total       0.79      0.79      0.79      1000
#
# APR: 0.850
# ROC: 0.869
# Elapsed time: 23.5 sec
# real	0m32.471s
# user	0m53.727s
# sys	0m1.463s

# %%
# %%bash
#
# # minimal call graphprot predict
# time ./graphprot_seqmodel -vv predict \
# -i /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa \
# -m out/model
# Out:
# --------------------------------------------------------------------------------
# Program: graphprot_seqmodel
# Called with parameters:
#  input_file: /home/maticzkd/projects/GraphProt/scratch/150526_prepare_gp_update_train_seqs/PARCLIP_QKI.ls.positives.fa
# model_file: out/model
# no_logging: False
# output_dir_path: out
#  verbosity: 2
#      which: predict
#
# 	Model parameters:
#
# Pre_processor:
#
#
# Vectorizer:
# complexity: 1
#
# Estimator:
#      alpha: 0.001
#       eta0: 0.001
#   l1_ratio: 0.344464087947
# learning_rate: optimal
#       loss: perceptron
#     n_iter: 54
#     n_jobs: -1
#    penalty: l2
#    power_t: 0.283384579189
# Written file: out/predictions.txt (500 lines)
# Written file: out/classifications.txt (500 lines)
# Written file: out/info.txt (500 lines)
# Elapsed time: 12.9 sec
# real	0m13.846s
# user	0m27.754s
# sys	0m0.681s
