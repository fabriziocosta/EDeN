# %%
# %pylab inline
import pylab as pl
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from eden import graph
from eden.util import eden_io
from eden.converters import gspan, node_link_data

from eden.util import display

# %%
g_it=gspan.gspan_to_eden('http://www.bioinf.uni-freiburg.de/~costa/rna.gspan')
g_list=[g for g in g_it]

# %%
print node_link_data.eden_to_node_link_data.__doc__
# Out:
# Takes a list of networkx graphs and yields serialised node_link_data JSON strings.

# %%
json_list=[s for s in node_link_data.eden_to_node_link_data(g_list)]
json_list[0]
# Out:
# '{"directed": false, "graph": [], "nodes": [{"hlabel": [12672038114], "id": 0, "viewpoint": true, "label": "c"}, {"hlabel": [12416037344], "id": 1, "viewpoint": true, "label": "a"}, {"hlabel": [12416037344], "id": 2, "viewpoint": true, "label": "a"}, {"hlabel": [12416037344], "id": 3, "viewpoint": true, "label": "a"}, {"hlabel": [12416037344], "id": 4, "viewpoint": true, "label": "a"}, {"hlabel": [13184039654], "id": 5, "viewpoint": true, "label": "g"}, {"hlabel": [14976045044], "id": 6, "viewpoint": true, "label": "u"}, {"hlabel": [12672038114], "id": 7, "viewpoint": true, "label": "c"}, {"hlabel": [14976045044], "id": 8, "viewpoint": true, "label": "u"}, {"hlabel": [13184039654], "id": 9, "viewpoint": true, "label": "g"}, {"hlabel": [13184039654], "id": 10, "viewpoint": true, "label": "g"}, {"hlabel": [13184039654], "id": 11, "viewpoint": true, "label": "g"}, {"hlabel": [12672038114], "id": 12, "viewpoint": true, "label": "c"}, {"hlabel": [14976045044], "id": 13, "viewpoint": true, "label": "u"}, {"hlabel": [12416037344], "id": 14, "viewpoint": true, "label": "a"}, {"hlabel": [12416037344], "id": 15, "viewpoint": true, "label": "a"}, {"hlabel": [13184039654], "id": 16, "viewpoint": true, "label": "g"}, {"hlabel": [12672038114], "id": 17, "viewpoint": true, "label": "c"}, {"hlabel": [12672038114], "id": 18, "viewpoint": true, "label": "c"}, {"hlabel": [12672038114], "id": 19, "viewpoint": true, "label": "c"}, {"hlabel": [12416037344], "id": 20, "viewpoint": true, "label": "a"}, {"hlabel": [12672038114], "id": 21, "viewpoint": true, "label": "c"}, {"hlabel": [14976045044], "id": 22, "viewpoint": true, "label": "u"}, {"hlabel": [13184039654], "id": 23, "viewpoint": true, "label": "g"}, {"hlabel": [12416037344], "id": 24, "viewpoint": true, "label": "a"}, {"hlabel": [12672038114], "id": 25, "viewpoint": true, "label": "c"}, {"hlabel": [13184039654], "id": 26, "viewpoint": true, "label": "g"}, {"hlabel": [12416037344], "id": 27, "viewpoint": true, "label": "a"}, {"hlabel": [13184039654], "id": 28, "viewpoint": true, "label": "g"}, {"hlabel": [12672038114], "id": 29, "viewpoint": true, "label": "c"}, {"hlabel": [12672038114], "id": 30, "viewpoint": true, "label": "c"}, {"hlabel": [13184039654], "id": 31, "viewpoint": true, "label": "g"}, {"hlabel": [12672038114], "id": 32, "viewpoint": true, "label": "c"}, {"hlabel": [14976045044], "id": 33, "viewpoint": true, "label": "u"}, {"hlabel": [13184039654], "id": 34, "viewpoint": true, "label": "g"}, {"hlabel": [13184039654], "id": 35, "viewpoint": true, "label": "g"}, {"hlabel": [13184039654], "id": 36, "viewpoint": true, "label": "g"}, {"hlabel": [12416037344], "id": 37, "viewpoint": true, "label": "a"}, {"hlabel": [14976045044], "id": 38, "viewpoint": true, "label": "u"}, {"hlabel": [12416037344], "id": 39, "viewpoint": true, "label": "a"}, {"hlabel": [12672038114], "id": 40, "viewpoint": true, "label": "c"}, {"hlabel": [13184039654], "id": 41, "viewpoint": true, "label": "g"}, {"hlabel": [13184039654], "id": 42, "viewpoint": true, "label": "g"}, {"hlabel": [12672038114], "id": 43, "viewpoint": true, "label": "c"}, {"hlabel": [13184039654], "id": 44, "viewpoint": true, "label": "g"}, {"hlabel": [12416037344], "id": 45, "viewpoint": true, "label": "a"}, {"hlabel": [12416037344], "id": 46, "viewpoint": true, "label": "a"}, {"hlabel": [12416037344], "id": 47, "viewpoint": true, "label": "a"}, {"hlabel": [12672038114], "id": 48, "viewpoint": true, "label": "c"}, {"hlabel": [14976045044], "id": 49, "viewpoint": true, "label": "u"}, {"hlabel": [14976045044], "id": 50, "viewpoint": true, "label": "u"}, {"hlabel": [14976045044], "id": 51, "viewpoint": true, "label": "u"}, {"hlabel": [14976045044], "id": 52, "viewpoint": true, "label": "u"}, {"hlabel": [13184039654], "id": 53, "viewpoint": true, "label": "g"}, {"hlabel": [9088027334], "id": 59, "viewpoint": true, "label": "G"}, {"hlabel": [10880032724], "id": 60, "viewpoint": true, "label": "U"}, {"hlabel": [8576025794], "id": 61, "viewpoint": ...

# %%
s='{"directed": false, "multigraph": false,   "graph": {"CASCADE_Id": "1", "Acc_No": "NC_017104", "Cas genes": "cas3-cas8e-cse2SS-cas7-cas5", "Subtype": "I-E"},  "nodes": [  {"id": 0,"weight": 312.570671378092, "label":"cluster11"},  {"id": 1,"weight": 300.1, "label":"M"},  {"id": 2,"weight": 300.1, "label":"P"},  {"id": 3,"weight": 300.1, "label":"Z"},  {"id": 4,"weight": 230.362548262548, "label":"cluster13"},  {"id": 5,"weight": 391.4, "label":"A"},  {"id": 6,"weight": 391.4, "label":"H"},  {"id": 7,"weight": 391.4, "label":"G"},  {"id": 8,"weight": 70.9, "label":"cluster12"},  {"id": 9,"weight": 81.8, "label":"N"},  {"id": 10,"weight": 81.8, "label":"K"},  {"id": 11,"weight": 81.8, "label":"E"},  {"id": 12,"weight": 308.531208053691, "label":"cluster9"},  {"id": 13,"weight": 398.2, "label":"D"},  {"id": 14,"weight": 398.2, "label":"D"},  {"id": 15,"weight": 398.2, "label":"T"},  {"id": 16,"weight": 160.900662251656, "label":"cluster7"},  {"id": 17,"weight": 134.8, "label":"F"},  {"id": 18,"weight": 134.8, "label":"R"},  {"id": 19,"weight": 134.8, "label":"R"}  ],  "links": [  {"source": 0,"target": 4, "label":"cascade"},  {"source": 0,"target": 1, "label":"part_of", "nesting": true},  {"source": 0,"target": 2, "label":"part_of", "nesting": true},  {"source": 0,"target": 3, "label":"part_of", "nesting": true},  {"source": 1,"target": 2, "label":"backbone"},  {"source": 2,"target": 3, "label":"backbone"},  {"source": 4,"target": 8, "label":"cascade"},  {"source": 4,"target": 5, "label":"part_of", "nesting": true},  {"source": 4,"target": 6, "label":"part_of", "nesting": true},  {"source": 4,"target": 7, "label":"part_of", "nesting": true},  {"source": 5,"target": 6, "label":"backbone"},  {"source": 6,"target": 7, "label":"backbone"},  {"source": 8,"target": 12, "label":"cascade"},  {"source": 8,"target": 9, "label":"part_of", "nesting": true},  {"source": 8,"target": 10, "label":"part_of", "nesting": true},  {"source": 8,"target": 11, "label":"part_of", "nesting": true},  {"source": 9,"target": 10, "label":"backbone"},  {"source": 10,"target": 11, "label":"backbone"},  {"source": 12,"target": 16, "label":"cascade"},  {"source": 12,"target": 13, "label":"part_of", "nesting": true},  {"source": 12,"target": 14, "label":"part_of", "nesting": true},  {"source": 12,"target": 15, "label":"part_of", "nesting": true},  {"source": 13,"target": 14, "label":"backbone"},  {"source": 14,"target": 15, "label":"backbone"},  {"source": 16,"target": 17, "label":"part_of", "nesting": true},  {"source": 16,"target": 18, "label":"part_of", "nesting": true},  {"source": 16,"target": 19, "label":"part_of", "nesting": true},  {"source": 17,"target": 18, "label":"backbone"},  {"source": 18,"target": 19, "label":"backbone"}]}'
#print json.dumps(json.loads(s), separators=(',',':'), indent=4)
json_list2=[s]
g_list2=[g for g in node_link_data.node_link_data_to_eden(json_list2)]
display.draw_graph(g_list2[0], size=17, node_size=600, node_border=0, layout='graphviz', prog = 'dot')

# %%
import json
s=json_list[0]
print json.dumps(json.loads(s), separators=(',',':'), indent=4)
# Out:
# {
#     "directed":false,
#     "graph":[],
#     "nodes":[
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":0,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":1,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":2,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":3,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":4,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":5,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 14976045044
#             ],
#             "id":6,
#             "viewpoint":true,
#             "label":"u"
#         },
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":7,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 14976045044
#             ],
#             "id":8,
#             "viewpoint":true,
#             "label":"u"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":9,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":10,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":11,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":12,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 14976045044
#             ],
#             "id":13,
#             "viewpoint":true,
#             "label":"u"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":14,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":15,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":16,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":17,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":18,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":19,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":20,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":21,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 14976045044
#             ],
#             "id":22,
#             "viewpoint":true,
#             "label":"u"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":23,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":24,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":25,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":26,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":27,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":28,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":29,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":30,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":31,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":32,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 14976045044
#             ],
#             "id":33,
#             "viewpoint":true,
#             "label":"u"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":34,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":35,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":36,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":37,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 14976045044
#             ],
#             "id":38,
#             "viewpoint":true,
#             "label":"u"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":39,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":40,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":41,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":42,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":43,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":44,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":45,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":46,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 12416037344
#             ],
#             "id":47,
#             "viewpoint":true,
#             "label":"a"
#         },
#         {
#             "hlabel":[
#                 12672038114
#             ],
#             "id":48,
#             "viewpoint":true,
#             "label":"c"
#         },
#         {
#             "hlabel":[
#                 14976045044
#             ],
#             "id":49,
#             "viewpoint":true,
#             "label":"u"
#         },
#         {
#             "hlabel":[
#                 14976045044
#             ],
#             "id":50,
#             "viewpoint":true,
#             "label":"u"
#         },
#         {
#             "hlabel":[
#                 14976045044
#             ],
#             "id":51,
#             "viewpoint":true,
#             "label":"u"
#         },
#         {
#             "hlabel":[
#                 14976045044
#             ],
#             "id":52,
#             "viewpoint":true,
#             "label":"u"
#         },
#         {
#             "hlabel":[
#                 13184039654
#             ],
#             "id":53,
#             "viewpoint":true,
#             "label":"g"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":59,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":60,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":61,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":62,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":63,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":64,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":65,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":66,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":67,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":68,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":69,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":70,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":71,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":72,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":73,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":74,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":75,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":76,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":77,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":78,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":79,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":94,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":95,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":96,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":97,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":98,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":99,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":118,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":119,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":120,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":121,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":122,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":123,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":124,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":125,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":126,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":127,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":128,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":129,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":130,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":131,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":132,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":140,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":141,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":142,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":143,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":158,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":159,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":160,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":161,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":162,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":163,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":164,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":165,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":166,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":167,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":168,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":169,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":170,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":171,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":172,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":173,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":174,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":175,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":176,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":177,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":178,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":179,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":180,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":181,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":182,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":184,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":185,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":186,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":187,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":188,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":189,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":191,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":192,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":193,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":194,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":195,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":196,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":197,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":198,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":199,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":200,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":201,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":202,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":203,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":204,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":205,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":206,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":207,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":208,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":209,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":210,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":211,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":212,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":213,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":214,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":215,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":216,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":217,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":218,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":219,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":220,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":221,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":222,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":223,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":224,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":225,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":226,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":227,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":228,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":229,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":230,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":231,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":232,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":233,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":234,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":235,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":236,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":237,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":238,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":239,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":240,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":241,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":242,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":243,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":244,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":245,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":246,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":247,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":248,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":249,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":250,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":251,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":252,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":253,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":254,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":255,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":256,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":257,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":258,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":264,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":265,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":266,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":267,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":268,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":269,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":270,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":271,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":272,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":273,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":274,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":275,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":276,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":277,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":278,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":279,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":280,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":281,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":282,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":283,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":284,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":285,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":286,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":287,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":288,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":289,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":290,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":291,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":292,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":293,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":294,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":295,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":296,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 10880032724
#             ],
#             "id":297,
#             "viewpoint":true,
#             "label":"U"
#         },
#         {
#             "hlabel":[
#                 8320025024
#             ],
#             "id":298,
#             "viewpoint":true,
#             "label":"A"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":299,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":300,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":301,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 8576025794
#             ],
#             "id":302,
#             "viewpoint":true,
#             "label":"C"
#         },
#         {
#             "hlabel":[
#                 9088027334
#             ],
#             "id":303,
#             "viewpoint":true,
#             "label":"G"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":313,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":314,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":315,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":316,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":317,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":318,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":319,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":320,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":321,
#             "viewpoint":true,
#             "label":"P"
#         },
#         {
#             "hlabel":[
#                 10240030801
#             ],
#             "id":322,
#             "viewpoint":true,
#             "label":"P"
#         }
#     ],
#     "links":[
#         {
#             "source":0,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":1,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":1,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":2,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":2,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":3,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":3,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":4,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":4,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":5,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":5,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":6,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":6,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":7,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":7,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":8,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":8,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":9,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":9,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":10,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":10,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":11,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":11,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":12,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":12,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":13,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":13,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":14,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":14,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":15,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":15,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":16,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":16,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":17,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":17,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":18,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":18,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":19,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":19,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":20,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":20,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":21,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":21,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":22,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":22,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":23,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":23,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":24,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":24,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":25,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":25,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":26,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":26,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":27,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":27,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":28,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":28,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":29,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":29,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":30,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":30,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":31,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":31,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":32,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":32,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":33,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":33,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":34,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":34,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":35,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":35,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":36,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":36,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":37,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":37,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":38,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":38,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":39,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":39,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":40,
#             "viewpoint":true,
# ...
#         },
#         {
#             "source":201,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":243,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":202,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":242,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":202,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":203,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":202,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":214,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":203,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":241,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":203,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":242,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":203,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":204,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":203,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":213,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":204,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":240,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":204,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":241,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":204,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":212,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":204,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":205,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":205,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":239,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":205,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":240,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":205,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":211,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":205,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":206,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":206,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":207,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":206,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":239,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":206,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":210,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":207,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":208,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":208,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":209,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":209,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":210,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":210,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":239,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":210,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":211,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":211,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":239,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":211,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":240,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":211,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":212,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":212,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":240,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":212,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":241,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":212,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":213,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":213,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":242,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":213,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":241,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":213,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":214,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":214,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":215,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":214,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":242,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":215,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":216,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":216,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":217,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":217,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":218,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":217,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":243,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":218,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":219,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":218,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":243,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":218,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":244,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":219,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":220,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":219,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":244,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":220,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":221,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":221,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":222,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":222,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":223,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":223,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":224,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":224,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":225,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":224,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":248,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":224,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":238,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":225,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":248,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":225,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":226,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":225,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":237,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":225,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":247,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":226,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":246,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":226,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":247,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":226,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":227,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":226,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":236,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":227,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":246,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":227,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":235,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":227,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":228,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":227,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":245,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":228,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":234,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":228,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":229,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":228,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":245,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":229,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":230,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":230,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":231,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":231,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":232,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":232,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":233,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":233,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":234,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":234,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":235,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":234,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":245,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":235,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":246,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":235,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":236,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":235,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":245,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":236,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":246,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":236,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":247,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":236,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":237,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":237,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":247,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":237,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":248,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":237,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":238,
#             "viewpoint":true,
#             "label":"."
#         },
#         {
#             "source":238,
#             "hlabel":[
#                 5888017711
#             ],
#             "target":248,
#             "viewpoint":true,
#             "label":"."
#         }
#     ],
#     "multigraph":false
# }

# %%
print node_link_data.node_link_data_to_eden.__doc__
# Out:
#     Takes a string list in the serialised node_link_data JSON format and yields networkx graphs.
#
#     Parameters
#     ----------
#     name : string
#         A pointer to the data source.
#
#     input_type : ['url','file','string_file']
#         If type is 'url' then 'name' is interpreted as a URL pointing to a file.
#         If type is 'file' then 'name' is interpreted as a file name.
#         If type is 'string_file' then 'name' is interpreted as a file name for a file
#         that contains strings rather than integers. The set of strings are mapped to
#         unique increasing integers and the corresponding vector of integers is returned.

# %%
graph_list=[g for g in  node_link_data.node_link_data_to_eden(json_list)]
display.draw_graph(graph_list[4], size=35, node_size=200, node_border=False, prog = 'fdp')
