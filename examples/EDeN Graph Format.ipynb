# %% [markdown]
# #Graph format
#
# The EDeN library allows the vectorization of graphs, i.e. the transformation of graphs into sparse vectors.
#
# The graphs that can be processed by the EDeN library have the following restrictions:
# - the graphs are implemented as *networkx* graphs
# - nodes and edges **must** have the 'label' attribute
# - the 'label' attribute can be of one of the following types: 1) a string, 2) a vector or 3) a dictionary; strings are used to represent categorical values; dictionaries are used to represent sparse vectors and are assumed to have string keys that encode an integer feature id and float values
# - nodes and edges **can** have a 'weight' attribute of float type
# - nodes that have to be considered in the vectorization **must** have a 'viewpoint' attribute of boolean type set to True
# - nesting edges **must** have a 'nesting' attribute of boolean type set to True

# %%
# %pylab inline
import pylab as pl
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Build graphs and then display them

# %%
import networkx as nx

graph_list = []

G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = 'A'
G.node[0]['class'] = 'CATEG'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = 'B'
G.node[1]['class'] = 'CATEG'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = 'C'
G.node[2]['class'] = 'CATEG'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'a'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'b'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]


G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = 'A'
G.node[0]['class'] = 'CATEG'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = 'B'
G.node[1]['class'] = 'CATEG'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = 'X'
G.node[2]['class'] = 'CATEG'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'a'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'b'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]

G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = 'A'
G.node[0]['class'] = 'CATEG'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = 'B'
G.node[1]['class'] = 'CATEG'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = 'X'
G.node[2]['class'] = 'CATEG'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'x'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'x'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]



G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = [1,0,0]
G.node[0]['class'] = 'VEC'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = [0,1,0]
G.node[1]['class'] = 'VEC'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = [0,0,1]
G.node[2]['class'] = 'VEC'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'a'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'b'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]


G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = [1,0.5,0]
G.node[0]['class'] = 'VEC'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = [0,1,0.5]
G.node[1]['class'] = 'VEC'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = [0,0.5,1]
G.node[2]['class'] = 'VEC'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'a'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'b'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]

G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = [1,0.5,0.5]
G.node[0]['class'] = 'VEC'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = [0.5,1,0.5]
G.node[1]['class'] = 'VEC'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = [0.5,0.5,1]
G.node[2]['class'] = 'VEC'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'a'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'b'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]


G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = {'1':1, '10':1, '100':1}
G.node[0]['class'] = 'SPVEC'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = {'11':1, '110':1, '1100':1}
G.node[1]['class'] = 'SPVEC'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = {'111':1, '1110':1, '11100':1}
G.node[2]['class'] = 'SPVEC'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'a'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'b'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]


G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = {'1':1, '10':10, '100':1}
G.node[0]['class'] = 'SPVEC'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = {'11':1, '110':10, '1100':1}
G.node[1]['class'] = 'SPVEC'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = {'111':1, '1110':10, '11100':1}
G.node[2]['class'] = 'SPVEC'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'a'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'b'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]



G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = {'1':10, '10':10, '100':10}
G.node[0]['class'] = 'SPVEC'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = {'11':10, '110':10, '1100':10}
G.node[1]['class'] = 'SPVEC'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = {'111':10, '1110':10, '11100':10}
G.node[2]['class'] = 'SPVEC'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'a'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'b'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]

from eden.util import display
for g in graph_list:
    display.draw_graph(g, size=5, node_size=800, node_border=1, layout='shell', secondary_vertex_label = 'class')

# %% [markdown]
# Create a vector representation

# %%
#%%time
from eden import graph
vec=graph.Vectorizer(r=1,d=1, discretization_size = 4, discretization_dimension = 5)
X=vec.fit_transform(graph_list)

print 'Instances: %d \nFeatures: %d with an avg of %d features per instance' % (X.shape[0], X.shape[1],  X.getnnz()/X.shape[0])
# Out:
# Instances: 9
# Features: 1048577 with an avg of 33 features per instance
# /Library/Python/2.7/site-packages/sklearn/cluster/k_means_.py:798: RuntimeWarning: Got data type int64, converted to float to avoid overflows
#   X = self._check_test_data(X)

# %%
# %%time
import numpy as np

#make dense feature representation
n_components = max(2, X.shape[0])

from sklearn.kernel_approximation import Nystroem
feature_map_nystroem = Nystroem(gamma=0.2, n_components=n_components)
X_explicit=feature_map_nystroem.fit_transform(X)

# Visualize result using PCA
from sklearn.decomposition import TruncatedSVD
pca = TruncatedSVD(n_components=2)
X_reduced = pca.fit_transform(X_explicit)
# Out:
# CPU times: user 15.3 ms, sys: 3.96 ms, total: 19.2 ms
# Wall time: 24.8 ms

# %% [markdown]
# 2D plot using OneClass classifier to identify density curves

# %%
# %%time

size=9
plt.figure(figsize=(size,size))

#make mesh
h = .01  # step size in the mesh
b = 0.1 # border size
x_min, x_max = X_reduced[:, 0].min() - b, X_reduced[:, 0].max() + b
y_min, y_max = X_reduced[:, 1].min() - b, X_reduced[:, 1].max() + b
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

from sklearn.svm import OneClassSVM
#induce a predictive model
clf = OneClassSVM(gamma = 10, nu = 0.01)
clf.fit(X_reduced)

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, m_max]x[y_min, y_max].
if hasattr(clf, "decision_function"):
    Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
else:
    Z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
# Put the result into a color plot
levels = np.linspace(min(Z), max(Z), 40)
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.get_cmap('YlOrRd'), alpha=.9,levels=levels)
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], 
            alpha=.5, 
            s=70, 
            edgecolors='none', 
            c = 'white',
            cmap = plt.get_cmap('YlOrRd'))
for id in range(len(graph_list)):
    label = str(id) 
    x = X_reduced[id, 0]
    y = X_reduced[id, 1]
    plt.annotate(label,xy = (x,y), xytext = (-12, -3), textcoords = 'offset points')
plt.show()
# Out:
# CPU times: user 303 ms, sys: 4.78 ms, total: 308 ms
# Wall time: 307 ms

# %% [markdown]
# Compute pairwise similarity matrix

# %%
from ipy_table import * 
def prep_table(K):    
    header = [' ']
    header += [i for i in range(K.shape[0])]
    mat = [header]
    for id, row in enumerate(K):
        new_row = [id]
        new_row += list(row)
        mat.append(new_row)
    return mat

# %%
from sklearn import metrics

K=metrics.pairwise.pairwise_kernels(X, metric='linear')

mat=prep_table(K)
make_table(mat)
apply_theme('basic')
set_global_style(float_format = '%0.2f')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>&nbsp</b></td><td  style="background-color:LightGray;"><b>0</b></td><td  style="background-color:LightGray;"><b>1</b></td><td  style="background-color:LightGray;"><b>2</b></td><td  style="background-color:LightGray;"><b>3</b></td><td  style="background-color:LightGray;"><b>4</b></td><td  style="background-color:LightGray;"><b>5</b></td><td  style="background-color:LightGray;"><b>6</b></td><td  style="background-color:LightGray;"><b>7</b></td><td  style="background-color:LightGray;"><b>8</b></td></tr><tr><td  style="background-color:Ivory;">0</td><td  style="background-color:Ivory;">1.00</td><td  style="background-color:Ivory;">0.37</td><td  style="background-color:Ivory;">0.29</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td></tr><tr><td  style="background-color:AliceBlue;">1</td><td  style="background-color:AliceBlue;">0.37</td><td  style="background-color:AliceBlue;">1.00</td><td  style="background-color:AliceBlue;">0.50</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.00</td></tr><tr><td  style="background-color:Ivory;">2</td><td  style="background-color:Ivory;">0.29</td><td  style="background-color:Ivory;">0.50</td><td  style="background-color:Ivory;">1.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td></tr><tr><td  style="background-color:AliceBlue;">3</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">1.00</td><td  style="background-color:AliceBlue;">0.76</td><td  style="background-color:AliceBlue;">0.36</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.00</td></tr><tr><td  style="background-color:Ivory;">4</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.76</td><td  style="background-color:Ivory;">1.00</td><td  style="background-color:Ivory;">0.67</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td></tr><tr><td  style="background-color:AliceBlue;">5</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.36</td><td  style="background-color:AliceBlue;">0.67</td><td  style="background-color:AliceBlue;">1.00</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.00</td><td  style="background-color:AliceBlue;">0.00</td></tr><tr><td  style="background-color:Ivory;">6</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">1.00</td><td  style="background-color:Ivory;">0.55</td><td  sty ...
