# %%
# %pylab inline
import pylab as pl
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from eden import graph
from eden.util import eden_io
from eden.converters import gspan, node_link_data

from eden.util import display

# %%
import networkx as nx

# %%
G = nx.Graph()
G.add_nodes_from([0,1,2])
G.add_edges_from([(0,1),(1,2)])
G.node[0]['label']=[0,0,1]
G.node[1]['label']=[0,1,0]
G.node[2]['label']=[1,0,0]
G.node[0]['viewpoint']=True
G.node[1]['viewpoint']=True
G.node[2]['viewpoint']=True
G.node[0]['class']='linear_A'
G.node[1]['class']='linear_A'
G.node[2]['class']='linear_A'
G.edge[0][1]['label']=[1]
G.edge[1][2]['label']=[1]
G.edge[0][1]['class']='linear_B'
G.edge[1][2]['class']='linear_B'
G1=G.copy()

# %%
G = nx.Graph()
G.add_nodes_from([0,1,2])
G.add_edges_from([(0,1),(1,2)])
G.node[0]['label']=[0,1,1]
G.node[1]['label']=[0,1,0]
G.node[2]['label']=[1,1,0]
G.node[0]['viewpoint']=True
G.node[1]['viewpoint']=True
G.node[2]['viewpoint']=True
G.node[0]['class']='linear_A'
G.node[1]['class']='linear_A'
G.node[2]['class']='linear_A'
G.edge[0][1]['label']=[1]
G.edge[1][2]['label']=[1]
G.edge[0][1]['class']='linear_B'
G.edge[1][2]['class']='linear_B'
G2=G.copy()

# %%
G = nx.Graph()
G.add_nodes_from([0,1,2])
G.add_edges_from([(0,1),(1,2)])
G.node[0]['label']=[0,0,3]
G.node[1]['label']=[0,3,0]
G.node[2]['label']=[3,0,0]
G.node[0]['viewpoint']=True
G.node[1]['viewpoint']=True
G.node[2]['viewpoint']=True
G.node[0]['class']='linear_A'
G.node[1]['class']='linear_A'
G.node[2]['class']='linear_A'
G.edge[0][1]['label']=[1]
G.edge[1][2]['label']=[1]
G.edge[0][1]['class']='linear_B'
G.edge[1][2]['class']='linear_B'
G3=G.copy()

# %%
G_list = [G1,G2,G3]

# %%
for G in G_list:
    display.draw_graph(G, size=6, 
                   node_size=2500, 
                   node_border=2, 
                   prog = 'neato', 
                   secondary_vertex_label='class', 
                   secondary_edge_label='class' )

# %%
vec=graph.Vectorizer(r = 1, d = 0, discretization_size = 3, discretization_dimension = 6)
X=vec.fit_transform(G_list)
print 'Instances: %d Features: %d with an avg of %d features per instance' % (X.shape[0], X.shape[1],  X.getnnz()/X.shape[0])
# Out:
# /home/costa/.local/lib/python2.7/site-packages/sklearn/cluster/k_means_.py:797: RuntimeWarning: Got data type int64, converted to float to avoid overflows
#   X = self._check_test_data(X)
#   (0, 263661)	0.575396455569
#   (0, 282285)	0.632455532034
#   (0, 355247)	0.0821994936527
#   (0, 549544)	0.246598480958
#   (0, 693479)	0.164398987305
#   (0, 738146)	0.246598480958
#   (0, 822641)	0.0821994936527
#   (0, 904463)	0.316227766017
#   (0, 930941)	0.0821994936527
#   (1, 263661)	0.624037720753
#   (1, 282285)	0.67990010365
#   (1, 355247)	0.0693375245282
#   (1, 549544)	0.277350098113
#   (1, 693479)	0.138675049056
#   (1, 738146)	0.0693375245282
#   (1, 822641)	0.0693375245282
#   (1, 904463)	0.194257172471
#   (2, 46467)	0.121267812518
#   (2, 103269)	0.242535625036
#   (2, 263661)	0.121267812518
#   (2, 282285)	0.471939903724
#   (2, 393877)	0.404519917478
#   (2, 482943)	0.242535625036
#   (2, 488293)	0.121267812518
#   (2, 535260)	0.242535625036
#   (2, 597869)	0.121267812518
#   (2, 738146)	0.242535625036
#   (2, 776356)	0.363803437554
#   (2, 904463)	0.337099931232
#   (2, 910964)	0.121267812518
#   (2, 971044)	0.242535625036
# Instances: 3 Features: 1048577 with an avg of 10 features per instance

# %%
from sklearn import metrics

K=metrics.pairwise.pairwise_kernels(X, metric='linear')
print K
# Out:
# [[ 1.          0.97019488  0.53466735]
#  [ 0.97019488  1.          0.47884858]
#  [ 0.53466735  0.47884858  1.        ]]
