# %% [markdown]
# #RNA family characterization
#
# Application scenario: we want to characterize the sequence patterns and structure of a set of RNA seqeunces

# %%
# %pylab inline
import pylab as pl
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Data acquisition

# %%
#RFAM id of a family
rf='RF00005'
#we compose the correspondent URL to fetch data from RFAM database
url_string='http://rfam.xfam.org/family/%s/alignment?acc=%s&format=fastau&download=0'%(rf,rf)
RNAshapes_options = {'shape_type' : 5, 'energy_range' : 25, 'max_num' : 1}

# %%
#we create an iterator that converts from FASTA to the Minimum Free Energy graph 
from eden.converter.RNA import RNA_SHAPE
graphs = RNA_SHAPE.RNA_SHAPE_to_eden(input = url_string, input_type = 'url', **RNAshapes_options)

from eden.modifier.RNA import structure as RNA_s
graphs = RNA_s.contraction_structure(graphs, level = 2)

#from eden.modifier.graph import vertex_attributes
#graphs = vertex_attributes.colorize(graphs)

#for sanity check we iterate on a handful (num) of seqeunces and display the MFE graph
num = 1
from eden.util import display
import itertools as it
for g in it.islice(graphs, num):
    display.draw_graph(g,size=12,node_border = False, node_size = 200, 
                       #secondary_vertex_label = 'weight',
                       vertex_color = 'weight', colormap='Spectral')
# Out:
# /Library/Python/2.7/site-packages/pygraphviz/agraph.py:1281: RuntimeWarning: Fontconfig warning: ignoring UTF-8: not a valid region tag
#
#   warnings.warn("".join(errors),RuntimeWarning)

# %%
#we create an iterator that converts from FASTA to the Minimum Free Energy graph 
from eden.converter.RNA import RNA_SHAPE
graphs = RNA_SHAPE.RNA_SHAPE_to_eden(input = url_string, input_type = 'url', **RNAshapes_options)

from eden.modifier.RNA import structure as RNA_s
graphs = RNA_s.contraction_structure(graphs, level = 2)

#from eden.modifier.graph import vertex_attributes
#graphs = vertex_attributes.colorize(graphs)

#for sanity check we iterate on a handful (num) of seqeunces and display the MFE graph
num = 1
from eden.util import display
import itertools as it
for g in it.islice(graphs, num):
    print display.serialize_graph(g)
# Out:
# {
#     "directed":false,
#     "graph":[
#         [
#             "name",
#             "disjoint_union( ,  )"
#         ],
#         [
#             "ID",
#             ">AB003409.1/96-167"
#         ]
#     ],
#     "nodes":[
#         {
#             "weight":2,
#             "contracted":[
#                 0,
#                 70
#             ],
#             "label":"----==",
#             "position":0,
#             "type":"----==",
#             "id":0
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 1
#             ],
#             "label":"-----===",
#             "position":1,
#             "type":"-----===",
#             "id":1
#         },
#         {
#             "weight":29,
#             "contracted":[
#                 64,
#                 65,
#                 2,
#                 3,
#                 68,
#                 69,
#                 6,
#                 7,
#                 8,
#                 9,
#                 10,
#                 11,
#                 12,
#                 66,
#                 13,
#                 17,
#                 18,
#                 67,
#                 4,
#                 5,
#                 44,
#                 45,
#                 46,
#                 47,
#                 48,
#                 49,
#                 50,
#                 51,
#                 52
#             ],
#             "label":"------===",
#             "position":2,
#             "type":"------===",
#             "id":2
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 14
#             ],
#             "label":"------==",
#             "position":14,
#             "type":"------==",
#             "id":14
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 15
#             ],
#             "label":"----==",
#             "position":15,
#             "type":"----==",
#             "id":15
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 16
#             ],
#             "label":"------==",
#             "position":16,
#             "type":"------==",
#             "id":16
#         },
#         {
#             "weight":2,
#             "contracted":[
#                 43,
#                 19
#             ],
#             "label":"------==",
#             "position":19,
#             "type":"------==",
#             "id":19
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 20
#             ],
#             "label":"----=",
#             "position":20,
#             "type":"----=",
#             "id":20
#         },
#         {
#             "weight":3,
#             "contracted":[
#                 21,
#                 22,
#                 23
#             ],
#             "label":"----",
#             "position":21,
#             "type":"----",
#             "id":21
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 24
#             ],
#             "label":"----=",
#             "position":24,
#             "type":"----=",
#             "id":24
#         },
#         {
#             "weight":2,
#             "contracted":[
#                 25,
#                 41
#             ],
#             "label":"------==",
#             "position":25,
#             "type":"------==",
#             "id":25
#         },
#         {
#             "weight":8,
#             "contracted":[
#                 37,
#                 38,
#                 39,
#                 40,
#                 26,
#                 27,
#                 28,
#                 29
#             ],
#             "label":"------===",
#             "position":26,
#             "type":"------===",
#             "id":26
#         },
#         {
#             "weight":2,
#             "contracted":[
#                 36,
#                 30
#             ],
#             "label":"------==",
#             "position":30,
#             "type":"------==",
#             "id":30
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 31
#             ],
#             "label":"----=",
#             "position":31,
#             "type":"----=",
#             "id":31
#         },
#         {
#             "weight":3,
#             "contracted":[
#                 32,
#                 33,
#                 34
#             ],
#             "label":"----",
#             "position":32,
#             "type":"----",
#             "id":32
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 35
#             ],
#             "label":"----=",
#             "position":35,
#             "type":"----=",
#             "id":35
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 42
#             ],
#             "label":"----==",
#             "position":42,
#             "type":"----==",
#             "id":42
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 53
#             ],
#             "label":"------==",
#             "position":53,
#             "type":"------==",
#             "id":53
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 54
#             ],
#             "label":"----=",
#             "position":54,
#             "type":"----=",
#             "id":54
#         },
#         {
#             "weight":7,
#             "contracted":[
#                 55,
#                 56,
#                 57,
#                 58,
#                 59,
#                 60,
#                 61
#             ],
#             "label":"----",
#             "position":55,
#             "type":"----",
#             "id":55
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 62
#             ],
#             "label":"----=",
#             "position":62,
#             "type":"----=",
#             "id":62
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 63
#             ],
#             "label":"------==",
#             "position":63,
#             "type":"------==",
#             "id":63
#         },
#         {
#             "weight":1,
#             "contracted":[
#                 71
#             ],
#             "label":"--=",
#             "position":71,
#             "type":"--=",
#             "id":71
#         }
#     ],
#     "links":[
#         {
#             "source":0,
#             "type":"backbone",
#             "target":1,
#             "label":"-"
#         },
#         {
#             "source":0,
#             "type":"backbone",
#             "target":2,
#             "label":"-"
#         },
#         {
#             "source":0,
#             "type":"backbone",
#             "target":22,
#             "label":"-"
#         },
#         {
#             "source":1,
#             "type":"basepair",
#             "target":2,
#             "label":"="
#         },
#         {
#             "source":2,
#             "type":"basepair",
#             "target":3,
#             "label":"="
#         },
#         {
#             "source":2,
#             "type":"backbone",
#             "target":5,
#             "label":"-"
#         },
#         {
#             "source":2,
#             "type":"backbone",
#             "target":6,
#             "label":"-"
#         },
#         {
#             "source":2,
#             "type":"backbone",
#             "target":17,
#             "label":"-"
#         },
#         {
#             "source":2,
#             "type":"backbone",
#             "target":21,
#             "label":"-"
#         },
#         {
#             "source":3,
#             "type":"backbone",
#             "target":4,
#             "label":"-"
#         },
#         {
#             "source":4,
#             "type":"backbone",
#             "target":5,
#             "label":"-"
#         },
#         {
#             "source":6,
#             "type":"backbone",
#             "target":7,
#             "label":"-"
#         },
#         {
#             "source":6,
#             "type":"backbone",
#             "target":16,
#             "label":"-"
#         },
#         {
#             "source":7,
#             "type":"backbone",
#             "target":8,
#             "label":"-"
#         },
#         {
#             "source":8,
#             "type":"backbone",
#             "target":9,
#             "label":"-"
#         },
#         {
#             "source":9,
#             "type":"backbone",
#             "target":10,
#             "label":"-"
#         },
#         {
#             "source":10,
#             "type":"backbone",
#             "target":11,
#             "label":"-"
#         },
#         {
#             "source":10,
#             "type":"backbone",
#             "target":16,
#             "label":"-"
#         },
#         {
#             "source":11,
#             "type":"backbone",
#             "target":12,
#             "label":"-"
#         },
#         {
#             "source":12,
#             "type":"backbone",
#             "target":15,
#             "label":"-"
#         },
#         {
#             "source":12,
#             "type":"backbone",
#             "target":13,
#             "label":"-"
#         },
#         {
#             "source":13,
#             "type":"backbone",
#             "target":14,
#             "label":"-"
#         },
#         {
#             "source":14,
#             "type":"backbone",
#             "target":15,
#             "label":"-"
#         },
#         {
#             "source":17,
#             "type":"backbone",
#             "target":18,
#             "label":"-"
#         },
#         {
#             "source":18,
#             "type":"backbone",
#             "target":19,
#             "label":"-"
#         },
#         {
#             "source":19,
#             "type":"backbone",
#             "target":20,
#             "label":"-"
#         },
#         {
#             "source":20,
#             "type":"backbone",
#             "target":21,
#             "label":"-"
#         }
#     ],
#     "multigraph":false
# }

# %% [markdown]
# Vectorization setup

# %%
#we set the 'resolution' of the vectorization
#the radius parameter is equivalent to the pixel resoultion in an image 
max_radius=1
#the distance parameter is equivalent to the number of colors in an image
max_distance=0
#a vectorizer object can then be instanciated
from eden import graph
vec=graph.Vectorizer(r=max_radius,d=max_distance)

# %% [markdown]
# Vectorization

# %%
# %%time
#we reset the iterator
graphs = RNA_SHAPE.RNA_SHAPE_to_eden(input = url_string, input_type = 'url', **RNAshapes_options)
from eden.modifier.RNA import structure as RNA_s
graphs = RNA_s.contraction_structure(graphs, level = 2)

#we employ the vectorizer to transform the graph instances into sparse vectors
#we collect all the vectors in a data matrix 
#depending on the number of instances and the desired resolution, the procedure can take from seconds to minutes for a few hundreds of sequences
X1=vec.transform(graphs, n_jobs=1)
print 'Instances: %d ; Features: %d with an avg of %d features per instance' % (X1.shape[0], X1.shape[1],  X1.getnnz()/X1.shape[0])
# Out:
# Instances: 945 ; Features: 1048577 with an avg of 19 features per instance
# CPU times: user 12.9 s, sys: 2.83 s, total: 15.7 s
# Wall time: 36.7 s

# %%
# %%time
#we create negative examples by randomly shuffling the input sequences 
from eden.modifier import FastaModifier
seqs = FastaModifier.shuffle(input = url_string, input_type = 'url').apply()
#we create an iterator that converts from FASTA to the Minimum Free Energy graph 
graphs = RNA_SHAPE.RNA_SHAPE_to_eden(input = seqs, input_type = 'list' , **RNAshapes_options)
from eden.modifier.RNA import structure as RNA_s
graphs = RNA_s.contraction_structure(graphs, level = 2)

X2=vec.transform(graphs, n_jobs=1)
print 'Instances: %d ; Features: %d with an avg of %d features per instance' % (X2.shape[0], X2.shape[1],  X2.getnnz()/X2.shape[0])
# Out:
# Instances: 904 ; Features: 1048577 with an avg of 23 features per instance
# CPU times: user 13.6 s, sys: 3.23 s, total: 16.9 s
# Wall time: 37.4 s

# %%
#...or we create the negative class from positive class data
# X2 = X1 * -1

# %%
#we concatenate the two data matrices into one matrix
#and we create a target vector that identifies with +1 and -1 the instances from the first or the second RNA family

from scipy.sparse import vstack
import numpy as np

#create target array
yp = [1] * X1.shape[0]
yn = [-1] * X2.shape[0]
y = np.array(yp + yn)
#update data matrix
X = vstack( [X1,X2] , format = "csr")
print 'Instances: %d ; Features: %d with an avg of %d features per instance' % (X.shape[0], X.shape[1],  X.getnnz()/X.shape[0])
# Out:
# Instances: 1849 ; Features: 1048577 with an avg of 21 features per instance

# %% [markdown]
# Fit a predictor

# %%
# %%time
#induce a stochastic gradient descent SVM predictive model
from sklearn.linear_model import SGDClassifier
from sklearn.grid_search import RandomizedSearchCV
from sklearn import cross_validation
from scipy.stats import randint
from scipy.stats import uniform
import numpy as np
from scipy import stats

predictor = SGDClassifier()
#hyperparameter optimization
param_dist = {"n_iter": randint(5, 100),
              "power_t": uniform(0.1),
              "alpha": uniform(1e-08,1e-03),
              "eta0" : uniform(1e-03,10),
              "penalty": ["l1", "l2", "elasticnet"],
              "learning_rate": ["invscaling", "constant","optimal"]}

scoring = 'roc_auc'
n_iter_search = 20
random_search = RandomizedSearchCV(predictor,param_distributions=param_dist,n_iter=n_iter_search,cv=5,scoring=scoring,n_jobs=8)
random_search.fit(X, y)
optpredictor= SGDClassifier(shuffle=True, n_jobs=8, **random_search.best_params_)

#fit the predictor on all available data
optpredictor.fit(X,y)
# Out:
# CPU times: user 850 ms, sys: 168 ms, total: 1.02 s
# Wall time: 5.45 s

# %%
# %%time
print 'Classifier:'
print optpredictor
print '-'*80

print 'Predictive performance:'
#assess the generalization capacity of the model via a 10-fold cross validation
for scoring in ['precision', 'recall', 'f1', 'average_precision', 'roc_auc']:
    scores = cross_validation.cross_val_score(optpredictor, X, y,cv=10, scoring=scoring, n_jobs=8)
    print('%20s: %.3f +- %.3f' % (scoring, np.mean(scores),np.std(scores)))
print '-'*80
# Out:
# Classifier:
# SGDClassifier(alpha=0.000802257435136, class_weight=None, epsilon=0.1,
#        eta0=3.18047762835, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=78, n_jobs=8,
#        penalty='l2', power_t=0.744799221785, random_state=None,
#        shuffle=True, verbose=0, warm_start=False)
# --------------------------------------------------------------------------------
# Predictive performance:
#            precision: 0.987 +- 0.010
#               recall: 0.896 +- 0.039
#                   f1: 0.939 +- 0.023
#    average_precision: 0.983 +- 0.011
#              roc_auc: 0.978 +- 0.013
# --------------------------------------------------------------------------------
# CPU times: user 326 ms, sys: 198 ms, total: 524 ms
# Wall time: 4.12 s

# %% [markdown]
# Setup the Annotator

# %%
#the Annotator takes in input a vectorizer and a predictor
iann=graph.Annotator(estimator = optpredictor, vectorizer = vec)

# %%
#reset the FASTA to graph converter to the first RNA family
graphs = RNA_SHAPE.RNA_SHAPE_to_eden(input = url_string, input_type = 'url' , **RNAshapes_options)
from eden.modifier.RNA import structure as RNA_s
graphs = RNA_s.contraction_structure(graphs, level = 2)

# %%
#annotate with colors the discriminative importance of different regions of the structural graphs
start = 0
stop = 3
step = 1
for g in it.islice(iann.transform(graphs),start,stop,step):
    display.draw_graph(g, vertex_color='importance',size=15, node_size=200, node_border=False, 
                       colormap='RdYlGn', invert_colormap=False)

# %% [markdown]
# Display interactive graph

# %%
from eden.converter.RNA import RNA_SHAPE
graphs = RNA_SHAPE.RNA_SHAPE_to_eden(input = url_string, input_type = 'url' , **RNAshapes_options)
from eden.modifier.RNA import structure as RNA_s
graphs = RNA_s.contraction_structure(graphs, level = 2)

#from eden.modifier.RNA import structure
#graphs = structure.add_stacking_base_pairs(graphs)

start = 0
stop = 3
step = 1
import json
from networkx.readwrite import json_graph

class SetEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, set):
            return list(obj)
        return json.JSONEncoder.default(self, obj)
    
import itertools as it
for g in it.islice(graphs,start,stop,step):
    data = json_graph.node_link_data(g)
    with open('graph.json', 'w') as f:
        json.dump(data, f, indent=4, cls=SetEncoder)

# %%
# %%html
# <div id="d3-example" width="100%" ></div>
# <style>
# .node {stroke: #000; stroke-width: 1.5px;}
# .link {stroke: #999; stroke-opacity: .5;}
# </style>
# Out:
# <div id="d3-example" width="100%" ></div>
# <style>
# .node {stroke: #000; stroke-width: 1.5px;}
# .link {stroke: #999; stroke-opacity: .5;}
# </style>

# %%
# %%javascript
# // We load the d3.js library from the Web.
# require.config({paths: {d3: "http://d3js.org/d3.v3.min"}});
# require(["d3"], function(d3) {
#     // The code in this block is executed when the
#     // d3.js library has been loaded.
#
#     // First, we specify the size of the canvas containing
#     // the visualization (size of the <div> element).
#     var width = 900,
#         height = 500;
#
#     // We create a color scale.
#     var color = d3.scale.category10();
#
#     // We create a force-directed dynamic graph layout.
#     var force = d3.layout.force()
#         .charge(-30)
#         .linkDistance(4)
#         .size([width, height]);
#
#     // In the <div> element, we create a <svg> graphic
#     // that will contain our interactive visualization.
#     var svg = d3.select("#d3-example").select("svg")
#     if (svg.empty()) {
#         svg = d3.select("#d3-example").append("svg")
#                     .attr("width", width)
#                     .attr("height", height);
#     }
#
#     // We load the JSON file.
#     d3.json("graph.json", function(error, graph) {
#         // In this block, the file has been loaded
#         // and the 'graph' object contains our graph.
#
#         // We load the nodes and links in the force-directed
#         // graph.
#         force.nodes(graph.nodes)
#             .links(graph.links)
#             .start();
#
#         // We create a <line> SVG element for each link
#         // in the graph.
#         var link = svg.selectAll(".link")
#             .data(graph.links)
#             .enter().append("line")
#             .attr("class", "link");
#
#         // We create a <circle> SVG element for each node
#         // in the graph, and we specify a few attributes.
#         var node = svg.selectAll(".node")
#             .data(graph.nodes)
#             .enter().append("circle")
#             .attr("class", "node")
#             .attr("r", 4)  // radius
#             .style("fill", function(d) {
#                 // The node color depends on the club.
#                 //c = Math.round(255*(d.weight*d.weight));
#                 return color(d.label);
#                 //return "rgb(100,110,110)";
#             })
#             .call(force.drag);
#
#         // The name of each node is the node number.
#         node.append("title")
#             .text(function(d) { return d.name; });
#
#         // We bind the positions of the SVG elements
#         // to the positions of the dynamic force-directed graph,
#         // at each time step.
#         force.on("tick", function() {
#             link.attr("x1", function(d) { return d.source.x; })
#                 .attr("y1", function(d) { return d.source.y; })
#                 .attr("x2", function(d) { return d.target.x; })
#                 .attr("y2", function(d) { return d.target.y; });
#
#             node.attr("cx", function(d) { return d.x; })
#                 .attr("cy", function(d) { return d.y; });
#         });
#     });
# });
