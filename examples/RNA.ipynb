# %% [markdown]
# #RNA family characterization
#
# Application scenario: we want to characterize RNA family A with respect to RNA family B, in other words, we are interested in identifying regions with their structural contexts that are characteristic of family A but not family B

# %%
# %pylab inline
import pylab as pl
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#given the RFAM id of a family we retrieve it from the RFAM online database
rf='RF00162'
#rf='RF00005'
#we compose the correspondent URL
url_string='http://rfam.xfam.org/family/%s/alignment?acc=%s&format=fastau&download=0'%(rf,rf)

# %%
#set the trapezoidal_reweighting parameters
high_weight = 1
low_weight = 0.1

high_weight_window_start = 20
high_weight_window_end =30

low_weight_window_start = 10
low_weight_window_end = 40

# %%
RNAshapes_options = {'shape_type' : 5, 'energy_range' : 5, 'max_num' : 2}

# %% [markdown]
# Data acquisition

# %%
#we use an iterator that converts from FASTA to the k-representative shapes graph 
from eden.converter.RNA import RNA_SHAPE
graphs = RNA_SHAPE.RNA_SHAPE_to_eden(input = url_string, input_type = 'url' , **RNAshapes_options )

from eden.modifier.graph import vertex_attributes as g_va
#graphs = g_va.trapezoidal_reweighting(graphs,high_weight = high_weight, low_weight = low_weight, high_weight_window_start = high_weight_window_start, high_weight_window_end = high_weight_window_end, low_weight_window_start = low_weight_window_start, low_weight_window_end = low_weight_window_end)


from eden.modifier.RNA import structure as RNA_s
graphs = RNA_s.abstract_structure(graphs, level = 1)

#from eden.modifier.RNA import vertex_attributes as RNA_va
#graphs = g_va.colorize(graphs, labels = ["A","U","o","G","C"])

#for sanity check we iterate on a handful (num) of seqeunces to display the resulting graph
from eden.util import display
import itertools as it


id = 2
start = id
stop = id+1
step = 1
for graph in it.islice(graphs,start,stop,step):
    display.draw_graph(graph, size=20, node_border = False, node_size = 400, 
                       vertex_label = 'label', 
                       vertex_color = 'weight', colormap = 'hot', invert_colormap = False)
# Out:
# /Library/Python/2.7/site-packages/pygraphviz/agraph.py:1281: RuntimeWarning: Fontconfig warning: ignoring UTF-8: not a valid region tag
#
#   warnings.warn("".join(errors),RuntimeWarning)

# %%
#we use an iterator that converts from FASTA to the k-representative shapes graph 
from eden.converter.RNA import RNA_SHAPE
graphs = RNA_SHAPE.RNA_SHAPE_to_eden(input = url_string, input_type = 'url' , **RNAshapes_options )

from eden.modifier.graph import vertex_attributes as g_va
graphs = g_va.trapezoidal_reweighting(graphs,high_weight = high_weight, low_weight = low_weight, high_weight_window_start = high_weight_window_start, high_weight_window_end = high_weight_window_end, low_weight_window_start = low_weight_window_start, low_weight_window_end = low_weight_window_end)

from eden.modifier.RNA import vertex_attributes as RNA_va
from eden.modifier.RNA import structure as RNA_s

graphs = g_va.colorize(graphs, labels = ["A","U","o","G","C"])

#for sanity check we iterate on a handful (num) of seqeunces to display the resulting graph
from eden.util import display
import itertools as it

id = 2
start = id
stop = id+1
step = 1
for graph in it.islice(graphs,start,stop,step):
    display.draw_graph(graph, size=20, node_border = False, node_size = 400, 
                       secondary_vertex_label = 'position',
                       vertex_color = 'weight', colormap = 'hot', invert_colormap = False)

# %% [markdown]
# Vectorization setup

# %%
#we set the 'resolution' of the vectorization
#the radius parameter is metaphorically equivalent to the pixel resolution in an image 
max_radius=1
#the distance parameter is metaphorically equivalent to the number of shades of colors in an image
max_distance=0
#a vectorizer object can then be instanciated
from eden import graph
vec=graph.Vectorizer(r=max_radius,d=max_distance)

# %% [markdown]
# Vectorization

# %%
# %%time
#we reset the iterator
rf='RF00162'
url_string='http://rfam.xfam.org/family/%s/alignment?acc=%s&format=fastau&download=0'%(rf,rf)
graphs = RNA_SHAPE.RNA_SHAPE_to_eden(input = url_string, input_type = 'url')

from eden.modifier.RNA import structure as RNA_s
graphs = RNA_s.abstract_structure(graphs, level = 1)

#we employ the vectorizer to transform the graph instances into sparse vectors
#we collect all the vectors in a data matrix 
#depending on the number of instances and the desired resolution, the procedure can take from seconds to minutes for a few hundreds of sequences
X1=vec.transform(graphs, n_jobs=1)
print 'Instances: %d ; Features: %d with an avg of %d features per instance' % (X1.shape[0], X1.shape[1],  X1.getnnz()/X1.shape[0])
# Out:
# Instances: 424 ; Features: 1048577 with an avg of 14 features per instance
# CPU times: user 35.7 s, sys: 4.01 s, total: 39.7 s
# Wall time: 1min 5s

# %%
# %%time
#we repeat the procedure for the second RNA family
rf='RF01725'
url_string='http://rfam.xfam.org/family/%s/alignment?acc=%s&format=fastau&download=0'%(rf,rf)
graphs = RNA_SHAPE.RNA_SHAPE_to_eden(input = url_string, input_type = 'url')

from eden.modifier.RNA import structure as RNA_s
graphs = RNA_s.abstract_structure(graphs, level = 1)


X2=vec.transform(graphs, n_jobs=1)
print 'Instances: %d ; Features: %d with an avg of %d features per instance' % (X2.shape[0], X2.shape[1],  X2.getnnz()/X2.shape[0])
# Out:
# Instances: 421 ; Features: 1048577 with an avg of 16 features per instance
# CPU times: user 21.2 s, sys: 2.18 s, total: 23.4 s
# Wall time: 39.1 s

# %%
#we concatenate the two data matrices into one matrix
#and we create a target vector that identifies with +1 and -1 the instances from the first or the second RNA family

from scipy.sparse import vstack
import numpy as np

#create target array
yp = [1] * X1.shape[0]
yn = [-1] * X2.shape[0]
y = np.array(yp + yn)
#update data matrix
X = vstack( [X1,X2] , format = "csr")
print 'Instances: %d ; Features: %d with an avg of %d features per instance' % (X.shape[0], X.shape[1],  X.getnnz()/X.shape[0])
# Out:
# Instances: 845 ; Features: 1048577 with an avg of 15 features per instance

# %% [markdown]
# Fit a predictor

# %%
# %%time
#induce a stochastic gradient descent SVM predictive model
from sklearn.linear_model import SGDClassifier
predictor = SGDClassifier()

#assess the generalization capacity of the model via a 10-fold cross validation
from sklearn import cross_validation
scores = cross_validation.cross_val_score(predictor, X, y,cv=10, scoring='roc_auc')

import numpy as np
print('AUC ROC: %.4f +- %.4f' % (np.mean(scores),np.std(scores)))
#AUC ROC values above 0.8 are indicative of a good generalization capacity
# Out:
# AUC ROC: 0.9079 +- 0.0391
# CPU times: user 339 ms, sys: 102 ms, total: 441 ms
# Wall time: 440 ms

# %%
#fit the predictor on all data
predictor.fit(X,y)
# Out:
# SGDClassifier(alpha=0.0001, class_weight=None, epsilon=0.1, eta0=0.0,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='optimal',
#        loss='hinge', n_iter=5, n_jobs=1, penalty='l2', power_t=0.5,
#        random_state=None, shuffle=False, verbose=0, warm_start=False)

# %% [markdown]
# Setup the Annotator

# %%
#the Annotator takes in input a vecotrizer and a predictor
iann=graph.Annotator(estimator = predictor, vectorizer = vec)

# %%
#reset the FASTA to graph converter to the first RNA family
rf='RF00162'
url_string='http://rfam.xfam.org/family/%s/alignment?acc=%s&format=fastau&download=0'%(rf,rf)
graphs = RNA_SHAPE.RNA_SHAPE_to_eden(input = url_string, input_type = 'url')

from eden.modifier.RNA import structure as RNA_s
graphs = RNA_s.abstract_structure(graphs, level = 1)

# %%
#annotate with colors the discriminative importance of different regions of the structural graphs
start = 0
stop = 5
step = 1
for graph in it.islice(iann.transform(graphs),start,stop,step):
    display.draw_graph(graph, vertex_color='importance', size = 20, node_size = 200, node_border=False, colormap='RdYlGn')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-1f1b45174466> in <module>()
#       3 stop = 5
#       4 step = 1
# ----> 5 for graph in it.islice(iann.transform(graphs),start,stop,step):
#       6     display.draw_graph(graph, vertex_color='importance', size = 20, node_size = 200, node_border=False, colormap='RdYlGn')
#
# /Users/costa/Desktop/BTSync/Projects/EDeN/EDeN/eden/graph.py in transform(self, G_list)
#     714         """
#     715         for G in G_list:
# --> 716             yield self._annotate(G)
#     717
#     718
#
# /Users/costa/Desktop/BTSync/Projects/EDeN/EDeN/eden/graph.py in _annotate(self, G_orig)
#     727         if self.relabel_vertex_with_vector:
#     728             G = self._annotate_vector(G, X)
# --> 729         return self._revert_edge_to_vertex_transform(G)
#     730
#     731
#
# /Users/costa/Desktop/BTSync/Projects/EDeN/EDeN/eden/graph.py in _revert_edge_to_vertex_transform(self, G_orig)
#     393                 #extract the endpoints
#     394                 endpoints = [u for u in G_orig.neighbors(n)]
# --> 395                 assert (len(endpoints) == 2), 'ERROR: more than 2 endpoints'
#     396                 u = endpoints[0]
#     397                 v = endpoints[1]
#
# AssertionError: ERROR: more than 2 endpoints
