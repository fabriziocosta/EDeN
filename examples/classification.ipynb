# %% [markdown]
# # Classification

# %% [markdown]
# Consider a binary classification problem. The data and target files are available online. The domain of the problem is chemoinformatics. Data is about toxicity of 4K small molecules.
# The creation of a predictive system happens in 3 steps:
#
# 1. *data conversion*: transform instances into a suitable graph format. This is done using specialized programs for each (domain, format) pair. In the example we have molecular graphs encoded using the gSpan format and we will therefore use the 'gspan' tool.
#
# 2. *data vectorization*: transform graphs into sparse vectors. This is done using the EDeN tool. The vectorizer accepts as parameters the (maximal) size of the fragments to be used as features, this is expressed as the pair 'radius' and the 'distance'. See for details: F. Costa, K. De Grave,''Fast Neighborhood Subgraph Pairwise Distance Kernel'', 27th International Conference on Machine Learning (ICML), 2010.
#
# 3. *modelling*: fit a predicitve system and evaluate its performance. This is done using the tools offered by the scikit library. In the example we will use a Stochastic Gradient Descent linear classifier.
#
# In the following cells there is the code for each step.

# %% [markdown]
# Install the library

# %%
# !pip install git+https://github.com/fabriziocosta/EDeN.git --user
# Out:
# Downloading/unpacking git+https://github.com/fabriziocosta/EDeN.git
#   Cloning https://github.com/fabriziocosta/EDeN.git to /var/folders/dt/rpzktt5x605914173xym42mh0000gn/T/pip-gNDTzI-build
#   Running setup.py (path:/var/folders/dt/rpzktt5x605914173xym42mh0000gn/T/pip-gNDTzI-build/setup.py) egg_info for package from git+https://github.com/fabriziocosta/EDeN.git
#
#   Requirement already satisfied (use --upgrade to upgrade): eden==02caf84 from git+https://github.com/fabriziocosta/EDeN.git in /Users/costa/Library/Python/2.7/lib/python/site-packages
# Downloading/unpacking numpy>=1.8.0 (from eden==02caf84)
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):   1%  57kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):   4%  155kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):   5%  204kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):   7%  278kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  10%  360kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  12%  438kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  15%  548kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  17%  638kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  20%  729kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  23%  835kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  27%  983kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  31%  1.1MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  33%  1.2MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  36%  1.3MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  39%  1.4MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  42%  1.5MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  45%  1.6MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  48%  1.7MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  50%  1.8MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  52%  1.9MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  54%  2.0MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  57%  2.1MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  60%  2.2MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  62%  2.3MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  64%  2.3MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  68%  2.5MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  70%  2.5MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  72%  2.6MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  77%  2.8MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  80%  2.9MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  83%  3.0MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  87%  3.1MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  89%  3.2MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  91%  3.3MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  93%  3.4MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  97%  3.5MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB): 100%  3.6MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB): 3.6MB downloaded
# Requirement already satisfied (use --upgrade to upgrade): scipy>=0.14.0 in /Library/Python/2.7/site-packages (from eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): scikit-learn in /Library/Python/2.7/site-packages (from eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): dill in /Library/Python/2.7/site-packages (from eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): networkx in /Library/Python/2.7/site-packages (from eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): matplotlib in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): biopython in /Library/Python/2.7/site-packages (from eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from matplotlib->eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): tornado in /Library/Python/2.7/site-packages (from matplotlib->eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): pyparsing>=1.5.6 in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from matplotlib->eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): nose in /Library/Python/2.7/site-packages (from matplotlib->eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): certifi in /Library/Python/2.7/site-packages (from tornado->matplotlib->eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): backports.ssl-match-hostname in /Library/Python/2.7/site-packages (from tornado->matplotlib->eden==02caf84)
# Installing collected packages: numpy
# Successfully installed numpy
# Cleaning up...

# %% [markdown]
# ### 1 Conversion

# %% [markdown]
# load a target file

# %%
input_target_url='http://www.bioinf.uni-freiburg.de/~costa/bursi.target'
from eden.util import eden_io
y=eden_io.load_target(input_target_url)

# %% [markdown]
# load data and convert it to graphs

# %%
#load data
input_data_url='http://www.bioinf.uni-freiburg.de/~costa/bursi.gspan'
from eden.graphicalizer.graph import gspan
g_it=gspan.gspan_to_eden(input = input_data_url, input_type = 'url')

# %% [markdown]
# ### 2 Vectorization

# %% [markdown]
# setup the vectorizer

# %%
#parameters setting
max_radius=3
min_radius=0
max_distance=0

from eden import graph
vec=graph.Vectorizer(r=max_radius,d=max_distance, min_r=min_radius)

# %% [markdown]
# extract features and build data matrix

# %%
# %%time
X=vec.transform(g_it, n_jobs=-1)
print 'Instances: %d Features: %d with an avg of %d features per instance' % (X.shape[0], X.shape[1],  X.getnnz()/X.shape[0])
# Out:
# Instances: 4337 Features: 1048577 with an avg of 34 features per instance
# CPU times: user 10.6 s, sys: 2.77 s, total: 13.4 s
# Wall time: 11.9 s

# %% [markdown]
# ### 3 Modelling

# %% [markdown]
# Induce a predictor and evaluate its performance

# %%
# %%time
#induce a predictive model
from sklearn.linear_model import SGDClassifier
predictor = SGDClassifier()

from sklearn import cross_validation
scores = cross_validation.cross_val_score(predictor, X, y,cv=10, scoring='roc_auc')

import numpy as np
print('AUC ROC: %.4f +- %.4f' % (np.mean(scores),np.std(scores)))
# Out:
# AUC ROC: 0.9000 +- 0.0150
# CPU times: user 403 ms, sys: 79.1 ms, total: 482 ms
# Wall time: 482 ms
