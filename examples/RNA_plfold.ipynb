# %%
# %pylab inline
import pylab as pl
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from eden.converter.RNA import RNA_PLFOLD

RNAplfold_options = {'window_size' : 150, 'max_bp_span' : 100, 'avg_bp_prob_cutoff' : 0.2, 'max_num_edges' : 2}

graphs = RNA_PLFOLD.RNA_PLFOLD_to_eden(input = '/scratch/0/uhlm/MIRNA/PYTHON/test.fa', input_type = 'file' , **RNAplfold_options )


# Ouput some graphs.
num = 1
from eden.util import display
import itertools as it
for g in it.islice(graphs,num):
    display.draw_graph(g, size=40, node_border = False, node_size = 400, 
                       secondary_vertex_label = 'position', secondary_edge_label = 'value')
