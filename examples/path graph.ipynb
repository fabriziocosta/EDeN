# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !pip install git+https://github.com/fabriziocosta/EDeN.git --user
# Out:
# Downloading/unpacking git+https://github.com/fabriziocosta/EDeN.git
#   Cloning https://github.com/fabriziocosta/EDeN.git to /var/folders/dt/rpzktt5x605914173xym42mh0000gn/T/pip-1ptVg0-build
#   Running setup.py (path:/var/folders/dt/rpzktt5x605914173xym42mh0000gn/T/pip-1ptVg0-build/setup.py) egg_info for package from git+https://github.com/fabriziocosta/EDeN.git
#   Requirement already satisfied (use --upgrade to upgrade): eden==02caf84 from git+https://github.com/fabriziocosta/EDeN.git in /Users/costa/Library/Python/2.7/lib/python/site-packages
# Downloading/unpacking numpy>=1.8.0 (from eden==02caf84)
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):   0%  12kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):   2%  77kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):   3%  143kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):   5%  212kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):   6%  241kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):   8%  319kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  11%  401kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  13%  495kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  16%  589kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  18%  671kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  20%  737kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  23%  839kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  25%  933kB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  28%  1.0MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  32%  1.2MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  34%  1.2MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  36%  1.3MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  40%  1.4MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  43%  1.6MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  46%  1.7MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  49%  1.8MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  51%  1.9MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  53%  1.9MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  56%  2.0MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  60%  2.2MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  63%  2.3MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  66%  2.4MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  68%  2.5MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  71%  2.6MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  74%  2.7MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  78%  2.8MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  81%  2.9MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  85%  3.1MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  86%  3.1MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  89%  3.2MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  93%  3.4MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  96%  3.5MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB):  99%  3.6MB
#   Downloading numpy-1.9.1-cp27-none-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.6MB): 3.6MB downloaded
# Requirement already satisfied (use --upgrade to upgrade): scipy>=0.14.0 in /Library/Python/2.7/site-packages (from eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): scikit-learn in /Library/Python/2.7/site-packages (from eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): dill in /Library/Python/2.7/site-packages (from eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): networkx in /Library/Python/2.7/site-packages (from eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): matplotlib in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): biopython in /Library/Python/2.7/site-packages (from eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from matplotlib->eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): tornado in /Library/Python/2.7/site-packages (from matplotlib->eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): pyparsing>=1.5.6 in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from matplotlib->eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): nose in /Library/Python/2.7/site-packages (from matplotlib->eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): certifi in /Library/Python/2.7/site-packages (from tornado->matplotlib->eden==02caf84)
# Requirement already satisfied (use --upgrade to upgrade): backports.ssl-match-hostname in /Library/Python/2.7/site-packages (from tornado->matplotlib->eden==02caf84)
# Installing collected packages: numpy
# Successfully installed numpy
# Cleaning up...

# %%
#swap two characters at random positions in a string 
import random

def one_swap(line):
    while True :
        id_i=random.randint(0,len(line)-1)
        id_j=random.randint(0,len(line)-1)
        id_start=min(id_i,id_j)
        id_end=max(id_i,id_j)
        if id_start != id_end and id_start != len(line)-1:
            a = line[0:id_start]
            b = line[id_start]
            c = line[id_start+1:id_end]
            d = line[id_end]
            e = line[id_end+1:]
            return  ''.join([a,d,c,b,e])

# %% [markdown]
# Build artificial dataset: starting from the string 'abcdefghijklmnopqrstuvwxyz', generate iteratively strings by swapping two characters at random. In this way instances are progressively more dissimilar

# %%
# %%time

data_size=500
rmax=3
dmax=6
data=[]
line=''.join([str(unichr(97+i)) for i in range(26)])
print line
for i in range(data_size):
    new_line=one_swap(line)
    data+=[new_line]
    line=new_line
# Out:
# abcdefghijklmnopqrstuvwxyz
# CPU times: user 3.75 ms, sys: 1.37 ms, total: 5.11 ms
# Wall time: 4.11 ms

# %% [markdown]
# compute the vector encoding of each instance in a sparse data matrix

# %%
# %%time
from eden import path_graph

vec=path_graph.Vectorizer(r=rmax,d=dmax)
X=vec.transform(data, n_jobs=1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-19c023be6e3a> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'from eden import path_graph\n\nvec=path_graph.Vectorizer(r=rmax,d=dmax)\nX=vec.transform(data, n_jobs=1)')
#
# /Library/Python/2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2160             magic_arg_s = self.var_expand(line, stack_depth)
#    2161             with self.builtin_trap:
# -> 2162                 result = fn(magic_arg_s, cell)
#    2163             return result
#    2164
#
# /Library/Python/2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#
# /Library/Python/2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Library/Python/2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1127         else:
#    1128             st = clock2()
# -> 1129             exec(code, glob, local_ns)
#    1130             end = clock2()
#    1131             out = None
#
# <timed exec> in <module>()
#
# ImportError: cannot import name path_graph

# %% [markdown]
# transform the sparse vector encoding into a dense vector encoding using the Nystroem approximation (using at most 'max_components').

# %%
# %%time
from sklearn.kernel_approximation import Nystroem
max_components=512
n_components=min(max_components,data_size)
feature_map_nystroem = Nystroem(n_components=n_components)
Xl=feature_map_nystroem.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ae33fd5f7f44> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'from sklearn.kernel_approximation import Nystroem\nmax_components=512\nn_components=min(max_components,data_size)\nfeature_map_nystroem = Nystroem(n_components=n_components)\nXl=feature_map_nystroem.fit_transform(X)')
#
# /Library/Python/2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2160             magic_arg_s = self.var_expand(line, stack_depth)
#    2161             with self.builtin_trap:
# -> 2162                 result = fn(magic_arg_s, cell)
#    2163             return result
#    2164
#
# /Library/Python/2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#
# /Library/Python/2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Library/Python/2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1127         else:
#    1128             st = clock2()
# -> 1129             exec(code, glob, local_ns)
#    1130             end = clock2()
#    1131             out = None
#
# <timed exec> in <module>()
#
# NameError: name 'X' is not defined

# %% [markdown]
# for visualization purposes, perform a manifold embedding in 2D using one of the following techniques: PCA, spectral, MDS, LLE, ISO.

# %%
# %%time
from sklearn import manifold

mode='LLE'
n_components=2
n_neighbors=5

if mode == 'PCA':
    emb = PCA(n_components=n_components)
elif mode == 'S':
    emb = manifold.SpectralEmbedding(n_components=n_components,n_neighbors=n_neighbors)
elif mode == 'MDS':
    emb = manifold.MDS(n_components, max_iter=30, n_init=1)
elif mode == 'LLE':
    emb = manifold.LocallyLinearEmbedding(n_neighbors,n_components,eigen_solver='auto',method='standard')
elif mode == 'ISO':
    emb = manifold.Isomap(n_neighbors=n_neighbors, n_components=n_components)

    
Xs = emb.fit_transform(Xl)
# Out:
# CPU times: user 240 ms, sys: 1.69 ms, total: 242 ms
# Wall time: 240 ms

# %%
import pylab as plt
plt.figure(figsize=(7,7))
plt.grid(True)

plt.plot(Xs[:,0],Xs[:,1], color='r')
plt.plot(Xs[:,0],Xs[:,1], marker='o', color='w')
