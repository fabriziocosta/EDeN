# %%
# %pylab inline
import pylab as pl
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Build graphs and then display them

# %%
import networkx as nx

graph_list = []

G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = 'A'
G.node[0]['class'] = 'CATEG'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = 'B'
G.node[1]['class'] = 'CATEG'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = 'C'
G.node[2]['class'] = 'CATEG'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'a'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'b'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]


G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = 'A'
G.node[0]['class'] = 'CATEG'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = 'B'
G.node[1]['class'] = 'CATEG'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = 'X'
G.node[2]['class'] = 'CATEG'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'a'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'b'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]

G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = 'A'
G.node[0]['class'] = 'CATEG'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = 'B'
G.node[1]['class'] = 'CATEG'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = 'X'
G.node[2]['class'] = 'CATEG'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'x'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'x'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]



G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = [1,0,0]
G.node[0]['class'] = 'VEC'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = [0,1,0]
G.node[1]['class'] = 'VEC'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = [0,0,1]
G.node[2]['class'] = 'VEC'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'a'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'b'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]


G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = [1,0.5,0]
G.node[0]['class'] = 'VEC'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = [0,1,0.5]
G.node[1]['class'] = 'VEC'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = [0,0.5,1]
G.node[2]['class'] = 'VEC'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'a'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'b'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]

G=nx.Graph()
G.add_node(0)
G.add_node(1)
G.add_node(2)
G.add_edge(0,1)
G.add_edge(1,2)
G.node[0]['label'] = [1,0.5,0.5]
G.node[0]['class'] = 'VEC'
G.node[0]['viewpoint'] = True

G.node[1]['label'] = [0.5,1,0.5]
G.node[1]['class'] = 'VEC'
G.node[1]['viewpoint'] = True

G.node[2]['label'] = [0.5,0.5,1]
G.node[2]['class'] = 'VEC'
G.node[2]['viewpoint'] = True

G.edge[0][1]['label'] = 'a'
G.edge[0][1]['class'] = 'CATEG_EDGE'
G.edge[0][1]['viewpoint'] = True


G.edge[1][2]['label'] = 'b'
G.edge[1][2]['class'] = 'CATEG_EDGE'
G.edge[1][2]['viewpoint'] = True

graph_list += [G.copy()]


from eden.util import display
for g in graph_list:
    display.draw_graph(g, size=5, node_size=800, node_border=1, layout='shell', secondary_vertex_label = 'class')

# %% [markdown]
# Create a vector representation

# %%
# %%time
from eden import graph
vec=graph.Vectorizer(r=1,d=1, discretization_size = 4, discretization_dimension = 7)
X=vec.fit_transform(graph_list)

print 'Instances: %d \nFeatures: %d with an avg of %d features per instance' % (X.shape[0], X.shape[1],  X.getnnz()/X.shape[0])
# Out:
# Instances: 6
# Features: 1048577 with an avg of 34 features per instance
# CPU times: user 166 ms, sys: 142 ms, total: 308 ms
# Wall time: 454 ms
# /Library/Python/2.7/site-packages/sklearn/cluster/k_means_.py:798: RuntimeWarning: Got data type int64, converted to float to avoid overflows
#   X = self._check_test_data(X)

# %% [markdown]
# Perform dimensionality reduction for 2D display

# %%
# %%time
import numpy as np

#make dense feature representation
n_components = max(2, X.shape[0]//2)

from sklearn.kernel_approximation import Nystroem
feature_map_nystroem = Nystroem(gamma=.1, n_components=n_components)
X_explicit=feature_map_nystroem.fit_transform(X)

# Visualize result using PCA
from sklearn.decomposition import TruncatedSVD
pca = TruncatedSVD(n_components=2)
X_reduced = pca.fit_transform(X_explicit)
# Out:
# CPU times: user 16.8 ms, sys: 9.23 ms, total: 26.1 ms
# Wall time: 36.5 ms

# %% [markdown]
# 2D plot using OneClass classifier to identify density curves

# %%
# %%time

size=9
plt.figure(figsize=(size,size))

#make mesh
h = .01  # step size in the mesh
b = 0.1 # border size
x_min, x_max = X_reduced[:, 0].min() - b, X_reduced[:, 0].max() + b
y_min, y_max = X_reduced[:, 1].min() - b, X_reduced[:, 1].max() + b
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

from sklearn.svm import OneClassSVM
#induce a predictive model
clf = OneClassSVM(gamma = 10, nu = 0.01)
clf.fit(X_reduced)

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, m_max]x[y_min, y_max].
if hasattr(clf, "decision_function"):
    Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
else:
    Z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
# Put the result into a color plot
levels = np.linspace(min(Z), max(Z), 40)
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.get_cmap('YlOrRd'), alpha=.9,levels=levels)
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], 
            alpha=.5, 
            s=70, 
            edgecolors='none', 
            c = 'white',
            cmap = plt.get_cmap('YlOrRd'))
for id in range(len(graph_list)):
    label = str(id) 
    x = X_reduced[id, 0]
    y = X_reduced[id, 1]
    plt.annotate(label,xy = (x,y), xytext = (-12, -3), textcoords = 'offset points')
plt.show()
# Out:
# CPU times: user 323 ms, sys: 6.18 ms, total: 329 ms
# Wall time: 329 ms

# %% [markdown]
# Compute pairwise similarity matrix

# %%
from ipy_table import * 
def prep_table(K):    
    header = [' ']
    header += [i for i in range(K.shape[0])]
    mat = [header]
    for id, row in enumerate(K):
        new_row = [id]
        new_row += list(row)
        mat.append(new_row)
    return mat

# %%
from sklearn import metrics

K=metrics.pairwise.pairwise_kernels(X, metric='linear')

mat=prep_table(K)
make_table(mat)
apply_theme('basic')
set_global_style(float_format = '%0.2f')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>&nbsp</b></td><td  style="background-color:LightGray;"><b>0</b></td><td  style="background-color:LightGray;"><b>1</b></td><td  style="background-color:LightGray;"><b>2</b></td><td  style="background-color:LightGray;"><b>3</b></td><td  style="background-color:LightGray;"><b>4</b></td><td  style="background-color:LightGray;"><b>5</b></td></tr><tr><td  style="background-color:Ivory;">0</td><td  style="background-color:Ivory;">1.00</td><td  style="background-color:Ivory;">0.37</td><td  style="background-color:Ivory;">0.29</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td><td  style="background-color:Ivory;">0.00</td></tr><tr><td  style="background-color:AliceBlue;">1</td><td  style="background-color:AliceBlue;">0.37</td><td  style="background-color:AliceBlue;">1.00</td><td  style="backgrou
# ...
